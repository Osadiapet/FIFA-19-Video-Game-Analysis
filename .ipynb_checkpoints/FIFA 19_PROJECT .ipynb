# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline 
plt.style.use('ggplot')

# %% [markdown]
# # STATISTICAL DATA ANALYSIS OF FIFA 19 PLAYER RATING

# %%
#load data
data=pd.read_csv("FIFA 19.csv", index_col=0)
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0      96.0    33.0            28.0          26.0       6.0        11.0
# 1      95.0    28.0            31.0          23.0       7.0        11.0
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 3      68.0    15.0            21.0          13.0      90.0        85.0
# 4      88.0    68.0            58.0          51.0      15.0        13.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 0       15.0          14.0        8.0        €226.5M
# 1       15.0          14.0       11.0        €127.1M
# 2       15.0          15.0       11.0        €228.1M
# 3       87.0          88.0       94.0        €138.6M
# 4        5.0          10.0       13.0        €196.4M
#
# [5 rows x 88 columns]

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
print('There is a total of {}'.format(data.shape[0], 'players in the dataset'))
# Out:
# There is a total of 18207

# %%
#descriptive statistics of players
data.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# 25%                    1.000000      3.000000      2.000000       8.000000
# 50%                    1.000000      3.000000      2.000000      17.000000
# 75%                    1.000000      3.000000      3.000000      26.000000
# max                    5.000000      5.000000      5.000000      99.000000
#
#            Crossing  ...     Penalties     Composure       Marking  \
# count  18159.000000  ...  18159.000000  18159.000000  18159.000000
# mean      49.734181  ...     48.548598     58.648274     47.281623
# std       18.364524  ...     15.704053     11.436133     19.904397
# min        5.000000  ...      5.000000      3.000000      3.000000
# 25%       38.000000  ...     39.000000     51.000000     30.000000
# 50%       54.000000  ...     49.000000     60.000000     53.000000
# 75%       64.000000  ...     60.000000     67.000000     64.000000
# max       93.000000  ...     92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.697836      45.661435     16.616223     16.391596
# std         21.664004      21.289135     17.695349     16.906900
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.232061      16.388898     16.710887
# std       16.502864      17.034669     17.955119
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 43 columns]

# %%
#getting the columns in the dataset
for col in data.columns:
    print(col)
# Out:
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
#checking if there are null values in the data 
data.isna().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Photo                0
# Nationality          0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 88, dtype: int64

# %%
#getting information about a DataFrame 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
#  13  Preferred Foot            18159 non-null  object
#  14  International Reputation  18159 non-null  float64
#  15  Weak Foot                 18159 non-null  float64
#  16  Skill Moves               18159 non-null  float64
#  17  Work Rate                 18159 non-null  object
#  18  Body Type                 18159 non-null  object
#  19  Real Face                 18159 non-null  object
#  20  Position                  18147 non-null  object
#  21  Jersey Number             18147 non-null  float64
#  22  Joined                    16654 non-null  object
#  23  Loaned From               1264 non-null   object
#  24  Contract Valid Until      17918 non-null  object
#  25  Height                    18159 non-null  object
#  26  Weight                    18159 non-null  object
#  27  LS                        16122 non-null  object
#  28  ST                        16122 non-null  object
#  29  RS                        16122 non-null  object
#  30  LW                        16122 non-null  object
#  31  LF                        16122 non-null  object
#  32  CF                        16122 non-null  object
#  33  RF                        16122 non-null  object
#  34  RW                        16122 non-null  object
#  35  LAM                       16122 non-null  object
#  36  CAM                       16122 non-null  object
#  37  RAM                       16122 non-null  object
#  38  LM                        16122 non-null  object
#  39  LCM                       16122 non-null  object
#  40  CM                        16122 non-null  object
#  41  RCM                       16122 non-null  object
#  42  RM                        16122 non-null  object
#  43  LWB                       16122 non-null  object
#  44  LDM                       16122 non-null  object
#  45  CDM                       16122 non-null  object
#  46  RDM                       16122 non-null  object
#  47  RWB                       16122 non-null  object
#  48  LB                        16122 non-null  object
#  49  LCB                       16122 non-null  object
#  50  CB                        16122 non-null  object
#  51  RCB                       16122 non-null  object
#  52  RB                        16122 non-null  object
#  53  Crossing                  18159 non-null  float64
#  54  Finishing                 18159 non-null  float64
#  55  HeadingAccuracy           18159 non-null  float64
#  56  ShortPassing              18159 non-null  float64
#  57  Volleys                   18159 non-null  float64
#  58  Dribbling                 18159 non-null  float64
#  59  Curve                     18159 non-null  float64
#  60  FKAccuracy                18159 non-null  float64
#  61  LongPassing               18159 non-null  float64
#  62  BallControl               18159 non-null  float64
#  63  Acceleration              18159 non-null  float64
#  64  SprintSpeed               18159 non-null  float64
#  65  Agility                   18159 non-null  float64
#  66  Reactions                 18159 non-null  float64
#  67  Balance                   18159 non-null  float64
#  68  ShotPower                 18159 non-null  float64
#  69  Jumping                   18159 non-null  float64
#  70  Stamina                   18159 non-null  float64
#  71  Strength                  18159 non-null  float64
#  72  LongShots                 18159 non-null  float64
#  73  Aggression                18159 non-null  float64
#  74  Interceptions             18159 non-null  float64
#  75  Positioning               18159 non-null  float64
#  76  Vision                    18159 non-null  float64
#  77  Penalties                 18159 non-null  float64
#  78  Composure                 18159 non-null  float64
#  79  Marking                   18159 non-null  float64
#  80  StandingTackle            18159 non-null  float64
#  81  SlidingTackle             18159 non-null  float64
#  82  GKDiving                  18159 non-null  float64
#  83  GKHandling                18159 non-null  float64
#  84  GKKicking                 18159 non-null  float64
#  85  GKPositioning             18159 non-null  float64
#  86  GKReflexes                18159 non-null  float64
#  87  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(5), object(45)
# memory usage: 12.4+ MB

# %%
#getting the number of distinct elements in each column 
data.nunique()
# Out:
# Unnamed: 0        18207
# ID                18207
# Name              17194
# Age                  29
# Photo             18207
#                   ...
# GKHandling           70
# GKKicking            79
# GKPositioning        79
# GKReflexes           76
# Release Clause     1244
# Length: 89, dtype: int64

# %% [markdown]
# # COUNTRIES WITH MOST PLAYERS

# %%
from collections import Counter
countries=Counter(data["Nationality"].values).most_common()
print(list(countries))
# Out:
# %% [markdown]
# # ANALYSIS OF PLAYERS PER EACH POSITION

# %%
#Best players in each position based on their overall scores 
data.loc[data.groupby(data["Position"])["Overall"].idxmax()]
data.loc[data.groupby(data["Position"])["Overall"].idxmax()][['Position', 'Name', "Age", "Nationality",'Club','Overall']]
# Out:
#     Position               Name  Age Nationality                      Club  \
# 17       CAM       A. Griezmann   27      France           Atlético Madrid
# 12        CB           D. Godín   32     Uruguay           Atlético Madrid
# 20       CDM    Sergio Busquets   29       Spain              FC Barcelona
# 271       CF       Luis Alberto   25       Spain                     Lazio
# 67        CM             Thiago   27       Spain         FC Bayern München
# 3         GK             De Gea   27       Spain         Manchester United
# 28       LAM       J. Rodríguez   26    Colombia         FC Bayern München
# 35        LB            Marcelo   30      Brazil               Real Madrid
# 24       LCB       G. Chiellini   33       Italy                  Juventus
# 11       LCM           T. Kroos   28     Germany               Real Madrid
# 14       LDM           N. Kanté   27      France                   Chelsea
# 5         LF          E. Hazard   27     Belgium                   Chelsea
# 33        LM      P. Aubameyang   29       Gabon                   Arsenal
# 21        LS          E. Cavani   31     Uruguay       Paris Saint-Germain
# 2         LW          Neymar Jr   26      Brazil       Paris Saint-Germain
# 474      LWB          N. Schulz   25     Germany       TSG 1899 Hoffenheim
# 129      RAM        J. Cuadrado   30    Colombia                  Juventus
# 69        RB        Azpilicueta   28       Spain                   Chelsea
# 8        RCB       Sergio Ramos   32       Spain               Real Madrid
# 4        RCM       K. De Bruyne   27     Belgium           Manchester City
# 45       RDM           P. Pogba   25      France         Manchester United
# 0         RF           L. Messi   31   Argentina              FC Barcelona
# 25        RM          K. Mbappé   19      France       Paris Saint-Germain
# 7         RS          L. Suárez   31     Uruguay              FC Barcelona
# 56        RW     Bernardo Silva   23    Portugal           Manchester City
# 450      RWB          M. Ginter   24     Germany  Borussia Mönchengladbach
# 1         ST  Cristiano Ronaldo   33    Portugal                  Juventus
#
#      Overall
# 17        89
# 12        90
# 20        89
# 271       82
# 67        86
# 3         91
# 28        88
# 35        88
# 24        89
# 11        90
# 14        89
# 5         91
# 33        88
# 21        89
# 2         92
# 474       80
# 129       84
# 69        86
# 8         91
# 4         91
# 45        87
# 0         94
# 25        88
# 7         91
# 56        86
# 450       80
# 1         94

# %%
#worst players in each of the positions 
data.loc[data.groupby(data["Position"])["Overall"].idxmin()][['Position','Name','Age','Nationality','Club',"Overall"]]
# Out:
#       Position                  Name  Age          Nationality  \
# 18170      CAM       Nicolas Firmino   17               Brazil
# 18165       CB             H. Norris   17              England
# 18192      CDM             S. Squire   18              England
# 18051       CF              C. Björk   18               Sweden
# 18206       CM             G. Nugent   16              England
# 18194       GK              J. Milli   18                Italy
# 9541       LAM             F. Sakala   21               Zambia
# 18191       LB  J. Norville-Williams   18              England
# 17290      LCB            K. Brouder   19  Republic of Ireland
# 18185      LCM              E. Tweed   19  Republic of Ireland
# 18167      LDM                Wu Lei   21             China PR
# 13178       LF           T. Matsuura   29                Japan
# 18154       LM            M. Roberts   17              England
# 16826       LS             G. Pender   24  Republic of Ireland
# 18038       LW          Zhen'ao Wang   18             China PR
# 18070      LWB          E. Dahlqvist   19               Sweden
# 11119      RAM             A. Fukuta   26                Japan
# 18187       RB             C. Ehlich   19              Germany
# 17453      RCB               E. Toal   19     Northern Ireland
# 17876      RCM          Yao Junsheng   22             China PR
# 17515      RDM             B. Rivera   18                Chile
# 10110       RF           L. Grozurek   26              Austria
# 18176       RM            T. Hillman   17                Wales
# 18011       RS              J. Ellis   17              England
# 18205       RW        D. Walker-Rice   17              England
# 18162      RWB          T. Gundelund   16              Denmark
# 18189       ST            A. Kaltner   18              Germany
#
#                              Club  Overall
# 18170      New England Revolution       48
# 18165             Oldham Athletic       48
# 18192            Cambridge United       47
# 18051              IFK Norrköping       50
# 18206             Tranmere Rovers       46
# 18194                       Lecce       47
# 9541                  KV Oostende       66
# 18191            Cambridge United       47
# 17290                 Limerick FC       54
# 18185                  Derry City       48
# 18167         Tianjin Quanjian FC       48
# 13178                Júbilo Iwata       62
# 18154            Northampton Town       48
# 16826              Bray Wanderers       56
# 18038              Vejle Boldklub       50
# 18070                IFK Göteborg       50
# 11119                  Sagan Tosu       64
# 18187          SpVgg Unterhaching       47
# 17453                  Derry City       54
# 17876  Shandong Luneng TaiShan FC       52
# 17515  CD Everton de Viña del Mar       54
# 10110               SK Sturm Graz       65
# 18176              Newport County       48
# 18011              Bray Wanderers       51
# 18205             Tranmere Rovers       47
# 18162              Vejle Boldklub       48
# 18189          SpVgg Unterhaching       47

# %% [markdown]
# # DETERMINING THE CORRELATION OF THE VARIOUS FEATURES

# %%
data[['Age','Crossing', 'International Reputation',
       'Skill Moves', 'Work Rate', 'Body Type','Overall', 'Potential', 'Value', 'Wage',
       'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
       'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']].corr()
# Out:
#                                Age  Crossing  International Reputation  \
# Age                       1.000000  0.130545                  0.253765
# Crossing                  0.130545  1.000000                  0.191770
# International Reputation  0.253765  0.191770                  1.000000
# Skill Moves               0.027649  0.741035                  0.208153
# Overall                   0.452350  0.394972                  0.499491
# Potential                -0.253312  0.246319                  0.372993
# Finishing                 0.068660  0.655300                  0.178373
# HeadingAccuracy           0.147183  0.469507                  0.157483
# ShortPassing              0.132894  0.809660                  0.242803
# Volleys                   0.142472  0.690339                  0.243089
# Dribbling                 0.010166  0.856647                  0.179041
# Curve                     0.143276  0.833105                  0.233681
# FKAccuracy                0.193467  0.761107                  0.223564
# LongPassing               0.181310  0.756527                  0.239525
# BallControl               0.084969  0.840916                  0.217946
# Acceleration             -0.158667  0.668365                  0.044319
# SprintSpeed              -0.151682  0.645578                  0.044070
# Agility                  -0.019395  0.698320                  0.100869
# Reactions                 0.453124  0.389574                  0.445614
# Balance                  -0.089877  0.618280                  0.050076
# ShotPower                 0.156947  0.705503                  0.227772
# Jumping                   0.177167  0.135486                  0.120931
# Stamina                   0.097793  0.672633                  0.094780
# Strength                  0.332798 -0.029403                  0.131280
# Composure                      0.317492 -0.378750   -0.375720  -0.374897
# Marking                        0.895908 -0.550978   -0.552263  -0.549498
# StandingTackle                 0.974659 -0.530989   -0.532160  -0.531092
# SlidingTackle                  1.000000 -0.509337   -0.510591  -0.509378
# GKDiving                      -0.509337  1.000000    0.970280   0.965685
# GKHandling                    -0.510591  0.970280    1.000000   0.965239
# GKKicking                     -0.509378  0.965685    0.965239   1.000000
# GKPositioning                 -0.505792  0.969864    0.969408   0.964336
# GKReflexes                    -0.509425  0.973320    0.970264   0.966337
#
#                           GKPositioning  GKReflexes
# Age                            0.116402    0.103313
# Crossing                      -0.660160   -0.662539
# International Reputation       0.006904    0.003444
# Skill Moves                   -0.618853   -0.621925
# Overall                       -0.017674   -0.023276
# Potential                     -0.052589   -0.053341
# Finishing                     -0.584852   -0.586913
# HeadingAccuracy               -0.744443   -0.748895
# ShortPassing                  -0.723782   -0.728721
# Volleys                       -0.586131   -0.588670
# Dribbling                     -0.751348   -0.754341
# Curve                         -0.603540   -0.604960
# FKAccuracy                    -0.552641   -0.554920
# LongPassing                   -0.591561   -0.595887
# BallControl                   -0.783607   -0.787939
# Acceleration                  -0.592143   -0.593201
# SprintSpeed                   -0.596498   -0.597837
# Agility                       -0.526983   -0.528899
# Reactions                     -0.055031   -0.059961
# Balance                       -0.503652   -0.505974
# ShotPower                     -0.651409   -0.653475
# Jumping                       -0.189079   -0.192050
# Stamina                       -0.696073   -0.699670
# Strength                      -0.103878   -0.107497
# LongShots                     -0.607200   -0.610087
# Aggression                    -0.571201   -0.575142
# Interceptions                 -0.481279   -0.486036
# Positioning                   -0.675569   -0.678582
# Vision                        -0.375775   -0.381158
# Penalties                     -0.617074   -0.619099
# Composure                     -0.370234   -0.377626
# Marking                       -0.546670   -0.551290
# StandingTackle                -0.527792   -0.531474
# SlidingTackle                 -0.505792   -0.509425
# GKDiving                       0.969864    0.973320
# GKHandling                     0.969408    0.970264
# GKKicking                      0.964336    0.966337
# GKPositioning                  1.000000    0.970130
# GKReflexes                     0.970130    1.000000
#
# [39 rows x 39 columns]

# %%
#looking at the heatmap for all features
plt.figure(figsize=(30,15))
plt.title("Heatmap for some features")
sns.heatmap(data[['Crossing','Overall', 'Potential', 'Value', 'Wage',
       'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
       'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle']].corr(), annot=True, linewidths=.5)
plt.show()

# %%
#univariate analysis of  attributes
fig, ax=plt.subplots(4,4, figsize=(20,8))
sns.distplot(data['Age'], ax=ax[0,0])
sns.distplot(data['Overall'], ax=ax[0,1])
sns.distplot(data['Finishing'], ax=ax[0,2])
sns.distplot(data['Crossing'], ax=ax[0,3])
sns.distplot(data['Finishing'], ax=ax[1,0])
sns.distplot(data['HeadingAccuracy'], ax=ax[1,1])
sns.distplot(data['ShortPassing'], ax=ax[1,2])
sns.distplot(data['LongPassing'], ax=ax[1,3])
sns.distplot(data['BallControl'], ax=ax[2,0])
sns.distplot(data['Acceleration'], ax=ax[2,1])
sns.distplot(data['SprintSpeed'], ax=ax[2,2])
sns.distplot(data['Agility'], ax=ax[2,3])
sns.distplot(data['Reactions'], ax=ax[3,0])
sns.distplot(data['Balance'], ax=ax[3,1])
sns.distplot(data['ShotPower'], ax=ax[3,2])
sns.distplot(data['Jumping'], ax=ax[3,3])
plt.tight_layout()

plt.show()

# %%
fig, ax=plt.subplots(3,4, figsize=(20,8))
sns.distplot(data['Stamina'], ax=ax[0,0])
sns.distplot(data['LongShots'], ax=ax[0,1])
sns.distplot(data['Aggression'], ax=ax[0,2])
sns.distplot(data['Interceptions'], ax=ax[0,3])
sns.distplot(data['Positioning'], ax=ax[1,0])
sns.distplot(data['Penalties'], ax=ax[1,1])
sns.distplot(data['Vision'], ax=ax[1,2])
sns.distplot(data['Composure'], ax=ax[1,3])
sns.distplot(data['Marking'], ax=ax[2,0])
sns.distplot(data['StandingTackle'], ax=ax[2,1])
sns.distplot(data['SlidingTackle'], ax=ax[2,2])
sns.distplot(data['SprintSpeed'], ax=ax[2,3])
plt.tight_layout()

plt.show()

# %%
#looking at some hidden facts in the dataset
oldest=data.loc[data['Age'].idxmax()]
youngest=data.loc[data["Age"].idxmin()]
best=data.loc[data["Overall"].idxmax()]
worst=data.loc[data["Overall"].idxmin()]
fast=data.loc[data["SprintSpeed"].idxmax()]
slow=data.loc[data["SprintSpeed"].idxmin()]
dribbler=data.loc[data["Dribbling"].idxmax()]
volley=data.loc[data["Volleys"].idxmax()]
jump=data.loc[data["Jumping"].idxmax()]
penalty=data.loc[data["Penalties"].idxmax()]
worst_p=data.loc[data["Penalties"].idxmin()]
intercept=data.loc[data["Interceptions"].idxmax()]
aggresive=data.loc[data["Aggression"].idxmax()]
vision=data.loc[data["Vision"].idxmax()]
GK=data.loc[data["GKReflexes"].idxmax()]
Gk_dive=data.loc[data["GKDiving"].idxmax()]
intl_repute=data.loc[data["International Reputation"].idxmax()]
agility=data.loc[data["Agility"].idxmax()]
stamina=data.loc[data["Stamina"].idxmax()]
control=data.loc[data["BallControl"].idxmax()]
shot=data.loc[data["ShotPower"].idxmax()]
acceleration=data.loc[data["Acceleration"].idxmax()]
marking=data.loc[data["Marking"].idxmax()]
long_passing=data.loc[data["LongPassing"].idxmax()]
free_kick=data.loc[data["FKAccuracy"].idxmax()]
finish=data.loc[data["Finishing"].idxmax()]
print("the oldest player is",data["Age"].max(),"years","." "His name is", oldest["Name"], "from", oldest["Nationality"], "and plays for", 
      oldest["Club"])
print("the youngest player is",data["Age"].min(),"." "His name is", youngest["Name"], "from", youngest["Nationality"],
      "and plays for", youngest["Club"])
print("the best player has an overall rating of",data["Overall"].max(),"." "His name is", best["Name"], "from", best["Nationality"],
      "and plays for", best["Club"])
print("The worst player has an overall rating of", data["Overall"].min(),".", "His name is", worst["Name"], "from",
     worst["Nationality"], "and plays for", worst["Club"])
print("The most fastest player has a sprint speed of", data["SprintSpeed"].max(),".", "His name is", fast["Name"], "from",
     fast["Nationality"], "and plays for", fast["Club"])
print("The most slowest player has a sprint speed of", data["SprintSpeed"].min(),".", "His name is", slow["Name"], "from",
     slow["Nationality"], "and plays for", slow["Club"])
print("The best dribbler has a dribbling ability of", data["Dribbling"].max(),".", "His name is", dribbler["Name"], "from",
     dribbler["Nationality"], "and plays for", dribbler["Club"])
print("The player who plays volley more than anyone has a Volley play ability of", data["Volleys"].max(),".", "His name is",
      volley["Name"], "from",volley["Nationality"], "and plays for", volley["Club"])
print("The player with the best jump has a jumping rate of", data["Jumping"].max(),".", "His name is", jump["Name"], "from",
     jump["Nationality"], "and plays for", jump["Club"])
print("The best penalty taker has a penalty taking ability of", data["Penalties"].max(),".", "His name is", penalty["Name"],
      "from",penalty["Nationality"], "and plays for", penalty["Club"])
print("The worst penalty taker has a penalty taking ability of", data["Penalties"].min(),".", "His name is", worst_p["Name"],
      "from",worst_p["Nationality"], "and plays for", worst_p["Club"])
print("The most aggressive player has a aggresive ability of", data["Aggression"].max(),".", "His name is", aggresive["Name"],
      "from", aggresive["Nationality"], "and plays for", aggresive["Club"])
print("The player with the best interception has an intercepting ability of", data["Interceptions"].max(),".", "His name is",
      intercept["Name"], "from",intercept["Nationality"], "and plays for", intercept["Club"])
print("The player with the best vision has a vision ability of", data["Vision"].max(),".", "His name is", vision["Name"], 
      "from",vision["Nationality"], "and plays for", vision["Club"])
print("The goalkeeper with good reflexes has a reflex ability of", data["GKReflexes"].max(),".", "His name is", GK["Name"], 
      "from", GK["Nationality"], "and plays for", GK["Club"])
print("The player with high international reputation has an international rating of ", data["International Reputation"].max(),".",
      "His name is", intl_repute["Name"], "from",intl_repute["Nationality"], "and plays for", intl_repute["Club"])
print("The goalkeeper with the highest diving ability has a diving ability of", data["GKDiving"].max(),".", "His name is", 
      Gk_dive["Name"], "from",Gk_dive["Nationality"], "and plays for", Gk_dive["Club"])
print("The player with the highest agility has agility rating of", data["Agility"].max(),".", "His name is", 
      agility["Name"], "from",agility["Nationality"], "and plays for", agility["Club"])
print("The player with the highest stamina has a stamina rating of", data["Stamina"].max(),".", "His name is", 
      stamina["Name"], "from",stamina["Nationality"], "and plays for", stamina["Club"])
print("The best controller of the ball has a ball control rate of", data["BallControl"].max(),".", "His name is", 
      control["Name"], "from",control["Nationality"], "and plays for", control["Club"])
print("The player with the most powerful shot has a shooting power of", data["ShotPower"].max(),".", "His name is", 
      shot["Name"], "from",shot["Nationality"], "and plays for", shot["Club"])
print("The player with the highest acceleration has an acceleration rating of", data["Acceleration"].max(),".", "His name is", 
      acceleration["Name"], "from",acceleration["Nationality"], "and plays for", acceleration["Club"])
print("The player who marks very well has a marking rating of", data["Marking"].max(),".", "His name is", 
      marking["Name"], "from",marking["Nationality"], "and plays for", marking["Club"])
print("The best freekick taker has an accuracy of", data["FKAccuracy"].max(),".", "His name is", 
      free_kick["Name"], "from",free_kick["Nationality"], "and plays for", free_kick["Club"])
print("The best long ball passer of the ball has a passing accuracy of", data["LongPassing"].max(),".", "His name is", 
      long_passing["Name"], "from",long_passing["Nationality"], "and plays for", long_passing["Club"])
print("The best finisher has a finishing rating of", data["Finishing"].max(),".", "His name is", 
      finish["Name"], "from",finish["Nationality"], "and plays for", finish["Club"])
# Out:
# the oldest player is 45 years .His name is O. Pérez from Mexico and plays for Pachuca
# the youngest player is 16 .His name is W. Geubbels from France and plays for AS Monaco
# the best player has an overall rating of 94 .His name is L. Messi from Argentina and plays for FC Barcelona
# The worst player has an overall rating of 46 . His name is G. Nugent from England and plays for Tranmere Rovers
# The most fastest player has a sprint speed of 96.0 . His name is K. Mbappé from France and plays for Paris Saint-Germain
# The most slowest player has a sprint speed of 12.0 . His name is K. Kirihata from Japan and plays for Kashiwa Reysol
# The best dribbler has a dribbling ability of 97.0 . His name is L. Messi from Argentina and plays for FC Barcelona
# The player who plays volley more than anyone has a Volley play ability of 90.0 . His name is E. Cavani from Uruguay and plays for Paris Saint-Germain
# The player with the best jump has a jumping rate of 95.0 . His name is Cristiano Ronaldo from Portugal and plays for Juventus
# The best penalty taker has a penalty taking ability of 92.0 . His name is M. Balotelli from Italy and plays for OGC Nice
# The worst penalty taker has a penalty taking ability of 5.0 . His name is E. Gründemann from Germany and plays for FC Hansa Rostock
# The most aggressive player has a aggresive ability of 95.0 . His name is B. Pearson from England and plays for Preston North End
# The player with the best interception has an intercepting ability of 92.0 . His name is N. Kanté from France and plays for Chelsea
# The player with the best vision has a vision ability of 94.0 . His name is L. Messi from Argentina and plays for FC Barcelona
# The goalkeeper with good reflexes has a reflex ability of 94.0 . His name is De Gea from Spain and plays for Manchester United
# The player with high international reputation has an international rating of  5.0 . His name is L. Messi from Argentina and plays for FC Barcelona
# The goalkeeper with the highest diving ability has a diving ability of 90.0 . His name is De Gea from Spain and plays for Manchester United
# The player with the highest agility has agility rating of 96.0 . His name is Neymar Jr from Brazil and plays for Paris Saint-Germain
# The player with the highest stamina has a stamina rating of 96.0 . His name is N. Kanté from France and plays for Chelsea
# The best controller of the ball has a ball control rate of 96.0 . His name is L. Messi from Argentina and plays for FC Barcelona
# The player with the most powerful shot has a shooting power of 95.0 . His name is Cristiano Ronaldo from Portugal and plays for Juventus
# The player with the highest acceleration has an acceleration rating of 97.0 . His name is Douglas Costa from Brazil and plays for Juventus
# The player who marks very well has a marking rating of 94.0 . His name is A. Barzagli from Italy and plays for Juventus
# The best freekick taker has an accuracy of 94.0 . His name is L. Messi from Argentina and plays for FC Barcelona
# The best long ball passer of the ball has a passing accuracy of 93.0 . His name is T. Kroos from Germany and plays for Real Madrid
# The best finisher has a finishing rating of 95.0 . His name is L. Messi from Argentina and plays for FC Barcelona

# %% [markdown]
# # LOOKING AT PREFERRED FOOT OF PLAYERS

# %%
#preferred foot of players
preferred=data["Preferred Foot"]
preferred_foot=preferred.dropna()
preferred_foot.value_counts()

preferred_foot=data["Preferred Foot"].value_counts()
plt.title("Distribution of players according to their preferred foot")
plt.pie(preferred_foot, labels=("Right","Left"),autopct='%1.1f%%')
plt.show()

# %%
ova=data.groupby('Name')['Overall'].max()
(ova.nlargest(10)).plot(kind="bar");
plt.title("Top 10 Players");

# %%
acceleration=data.groupby('Name')['Acceleration'].max()
(acceleration.nlargest(10)).plot(kind="bar");
plt.title("Players with the highest acceleration");

# %%
fk=data.groupby('Name')['FKAccuracy'].max()
(fk.nlargest(10)).plot(kind="bar");
plt.title("Top 10 FeeKick Takers");

# %%
pen=data.groupby('Name')['Penalties'].max()
(pen.nlargest(10)).plot(kind="bar");
plt.title("Top 10 Penalty Takers");

# %% [markdown]
# # ANALYSIS OF CLUB TEAMS

# %%
clubs=data["Club"].unique()
club_size=len(clubs)
total_players=data["Name"].count()
average_players=total_players/club_size
print('There are a total of',club_size,'clubs in the dataset.','and an average of',average_players,'players in each club')
# Out:
# There are a total of 652 clubs in the dataset. and an average of 27.92484662576687 players in each club

# %%
from collections import Counter
all_clubs=Counter(data["Club"].values).most_common()
print(all_clubs)
# Out:
# [(nan, 241), ('FC Barcelona', 33), ('Manchester United', 33), ('Manchester City', 33), ('Chelsea', 33), ('Real Madrid', 33), ('Atlético Madrid', 33), ('Tottenham Hotspur', 33), ('Liverpool', 33), ('Arsenal', 33), ('Borussia Dortmund', 33), ('Valencia CF', 33), ('RC Celta', 33), ('AS Monaco', 33), ('Everton', 33), ('TSG 1899 Hoffenheim', 33), ('Wolverhampton Wanderers', 33), ('Eintracht Frankfurt', 33), ('Burnley', 33), ('Southampton', 33), ('Newcastle United', 33), ('Frosinone', 33), ('CD Leganés', 33), ('Rayo Vallecano', 33), ('Empoli', 33), ('Cardiff City', 33), ('Fortuna Düsseldorf', 33), ('Lazio', 32), ('Villarreal CF', 32), ('Leicester City', 32), ('West Ham United', 32), ('Hertha BSC', 32), ('SV Werder Bremen', 32), ('Crystal Palace', 32), ('VfL Wolfsburg', 32), ('Levante UD', 32), ('Fulham', 32), ('1. FSV Mainz 05', 32), ('Bournemouth', 32), ('FC Nantes', 32), ('Brighton & Hove Albion', 32), ('Huddersfield Town', 32), ('Real Sociedad', 31), ('Athletic Club de Bilbao', 31), ('FC Augsburg', 31), ('Toulouse Football Club', 31), ('FC Girondins de Bordeaux', 31), ('Paris Saint-Germain', 30), ('Vissel Kobe', 30), ('Sporting CP', 30), ('Sevilla FC', 30), ('Ajax', 30), ('Borussia Mönchengladbach', 30), ('PSV', 30), ('Galatasaray SK', 30), ('Fenerbahçe SK', 30), ('Al Hilal', 30), ('Stoke City', 30), ('Portland Timbers', 30), ('Tigres U.A.N.L.', 30), ('Sagan Tosu', 30), ('Al Ahli', 30), ('SC Freiburg', 30), ('Querétaro', 30), ('Hamburger SV', 30), ('Al Wehda', 30), ('Al Ittihad', 30), ('West Bromwich Albion', 30), ('Club América', 30), ('Udinese', 30), ('Real Valladolid CF', 30), ('Vitória Guimarães', 30), ('Deportivo de La Coruña', 30), ('Swansea City', 30), ('Real Sporting de Gijón', 30), ('Angers SCO', 30), ('Antalyaspor', 30), ('Minnesota United FC', 30), ('Club León', 30), ('Leeds United', 30), ('Alanyaspor', 30), ('Derby County', 30), ('Kawasaki Frontale', 30), ('Aston Villa', 30), ('Málaga CF', 30), ('
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
big_teams["Club"].value_counts()
# Out:
# Borussia Dortmund      33
# Arsenal                33
# Manchester City        33
# Chelsea                33
# Liverpool              33
# Manchester United      33
# Real Madrid            33
# FC Barcelona           33
# Sevilla FC             30
# Paris Saint-Germain    30
# FC Bayern München      29
# Milan                  27
# Juventus               25
# Napoli                 25
# Inter                  24
# Name: Club, dtype: int64

# %%
#comparing the wages of players in the big teams
wages=big_teams['Wage'].str.replace('[€,M,K]','')
new_wages=wages.astype('int')
teams=big_teams["Club"]
plt.title("Distribution Teams with the Highest Wages ")
plt.bar(teams,new_wages.sort_values(ascending=False))
plt.xlabel("Teams")
plt.ylabel("Wages")
plt.xticks(rotation=90)
plt.show()

# %%
#looking at the overall ratings of the big teams 
overall=big_teams["Overall"]
teams=big_teams["Club"]
plt.title("distribution to compare the overall ratings of players in the big teams")
plt.bar(teams, overall)
plt.xlabel("Team")
plt.ylabel("Overall rating")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # ANALYSIS OF PLAYERS BY POSITION

# %% [markdown]
# # Goalkeepers

# %%
goalkeepers=["GK"]
goalkeepers=data[data["Position"].isin(goalkeepers)]
goalkeepers.head()
# Out:
#     Unnamed: 0      ID           Name  Age  \
# 3            3  193080         De Gea   27
# 9            9  200389       J. Oblak   25
# 18          18  192448  M. ter Stegen   26
# 19          19  192119    T. Courtois   26
# 22          22  167495       M. Neuer   32
#
#                                              Photo Nationality  \
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 9   https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 19  https://cdn.sofifa.org/players/4/19/192119.png     Belgium
# 22  https://cdn.sofifa.org/players/4/19/167495.png     Germany
#
#                                    Flag  Overall  Potential  \
# 3   https://cdn.sofifa.org/flags/45.png       91         93
# 9   https://cdn.sofifa.org/flags/44.png       90         93
# 18  https://cdn.sofifa.org/flags/21.png       89         92
# 19   https://cdn.sofifa.org/flags/7.png       89         90
# 22  https://cdn.sofifa.org/flags/21.png       89         89
#
#                  Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 3   Manchester United  ...      68.0    15.0           21.0           13.0
# 9     Atlético Madrid  ...      70.0    27.0           12.0           18.0
# 18       FC Barcelona  ...      69.0    25.0           13.0           10.0
# 19        Real Madrid  ...      66.0    20.0           18.0           16.0
# 22  FC Bayern München  ...      70.0    17.0           10.0           11.0
#
#    GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 3      90.0        85.0       87.0           88.0       94.0        €138.6M
# 9      86.0        92.0       78.0           88.0       89.0        €144.5M
# 18     87.0        85.0       88.0           85.0       90.0        €123.3M
# 19     85.0        91.0       72.0           86.0       88.0        €113.7M
# 22     90.0        86.0       91.0           87.0       87.0         €62.7M
#
# [5 rows x 89 columns]

# %%
total_keepers=goalkeepers["Name"].count()
print("There are a total of",total_keepers,"Goalkeepers in the FIFA 19 dataset")
# Out:
# There are a total of 2025 Goalkeepers in the FIFA 19 dataset

# %%
#descfriptive statistics of players
goalkeepers.describe()
# Out:
#          Unnamed: 0             ID          Age      Overall    Potential  \
# count   2025.000000    2025.000000  2025.000000  2025.000000  2025.000000
# mean   10333.056296  207877.391111    26.043457    64.603457    69.799012
# std     5540.048848   38728.503360     5.465042     7.596630     6.374247
# min        3.000000    1179.000000    16.000000    47.000000    48.000000
# 25%     5703.000000  191827.000000    22.000000    59.000000    65.000000
# 50%    10974.000000  216540.000000    25.000000    64.000000    69.000000
# 75%    15491.000000  235155.000000    30.000000    69.000000    74.000000
# max    18198.000000  246603.000000    45.000000    91.000000    93.000000
#
#            Special  International Reputation    Weak Foot  Skill Moves  \
# count  2025.000000               2025.000000  2025.000000       2025.0
# mean   1046.204938                  1.095802     2.489877          1.0
# std     131.561198                  0.374202     0.666847          0.0
# min     731.000000                  1.000000     1.000000          1.0
# 25%     949.000000                  1.000000     2.000000          1.0
# 50%    1060.000000                  1.000000     3.000000          1.0
# 75%    1138.000000                  1.000000     3.000000          1.0
# max    1473.000000                  5.000000     5.000000          1.0
#
#        Jersey Number  ...    Penalties    Composure      Marking  \
# count    2025.000000  ...  2025.000000  2025.000000  2025.000000
# mean       20.516543  ...    20.007407    45.122469    15.225185
# std        18.492143  ...     6.845878    12.093992     5.633895
# min         1.000000  ...     5.000000     3.000000     3.000000
# 25%         1.000000  ...    15.000000    36.000000    11.000000
# 50%        21.000000  ...    20.000000    46.000000    14.000000
# 75%        30.000000  ...    23.000000    55.000000    19.000000
# max        99.000000  ...    72.000000    71.000000    46.000000
#
#        StandingTackle  SlidingTackle     GKDiving   GKHandling    GKKicking  \
# count     2025.000000    2025.000000  2025.000000  2025.000000  2025.000000
# mean        14.141235      14.072099    65.323951    62.868148    61.477531
# std          3.425204       3.447909     7.768497     7.486476     7.626315
# min          2.000000       3.000000    45.000000    43.000000    35.000000
# 25%         12.000000      12.000000    60.000000    58.000000    56.000000
# 50%         14.000000      13.000000    65.000000    63.000000    61.000000
# 75%         16.000000      16.000000    70.000000    68.000000    66.000000
# max         33.000000      41.000000    90.000000    92.000000    91.000000
#
#        GKPositioning   GKReflexes
# count    2025.000000  2025.000000
# mean       63.047407    66.101728
# std         8.671413     8.213524
# min        38.000000    44.000000
# 25%        57.000000    60.000000
# 50%        63.000000    66.000000
# 75%        69.000000    72.000000
# max        90.000000    94.000000
#
# [8 rows x 44 columns]

# %%
old_GK=goalkeepers.loc[goalkeepers["Age"].idxmax()]
young_GK=goalkeepers.loc[goalkeepers["Age"].idxmin()]
best_GK=goalkeepers.loc[goalkeepers["Overall"].idxmax()]

print("The oldest goalkeeper is", old_GK["Name"], "He is", goalkeepers["Age"].max(), "from", old_GK["Nationality"], "and plays for", 
      old_GK["Club"], "He has a rating of", old_GK["Overall"])
print("The youngest goalkeeper is", young_GK["Name"], "He is", goalkeepers["Age"].min(), "from", young_GK["Nationality"], "and plays for", 
      young_GK["Club"], "He has a rating of", young_GK["Overall"])
print("The Best goalkeeper is", best_GK["Name"], "with rating of", goalkeepers["Overall"].max(), "from", best_GK["Nationality"],
      "and plays for", best_GK["Club"])
# Out:
# The oldest goalkeeper is O. Pérez He is 45 from Mexico and plays for Pachuca He has a rating of 71
# The youngest goalkeeper is K. Broda He is 16 from Poland and plays for Wisła Kraków He has a rating of 53
# The Best goalkeeper is De Gea with rating of 91 from Spain and plays for Manchester United

# %%
goalkeepers_percentage=(total_keepers)/len(data["Name"])*100
print("There is a percentage of",goalkeepers_percentage," % goalkeepers in the FIFA 19 dataset")
# Out:
# There is a percentage of 11.122095897182401  % goalkeepers in the FIFA 19 dataset

# %% [markdown]
# # Defenders

# %%
defenders=['LWB', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']
defenders=data[data["Position"].isin(defenders)]
defenders.head()
# Out:
#     Unnamed: 0      ID          Name  Age  \
# 8            8  155862  Sergio Ramos   32
# 12          12  182493      D. Godín   32
# 24          24  138956  G. Chiellini   33
# 34          34  178603    M. Hummels   29
# 35          35  176676       Marcelo   30
#
#                                              Photo Nationality  \
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 12  https://cdn.sofifa.org/players/4/19/182493.png     Uruguay
# 24  https://cdn.sofifa.org/players/4/19/138956.png       Italy
# 34  https://cdn.sofifa.org/players/4/19/178603.png     Germany
# 35  https://cdn.sofifa.org/players/4/19/176676.png      Brazil
#
#                                    Flag  Overall  Potential  \
# 8   https://cdn.sofifa.org/flags/45.png       91         91
# 12  https://cdn.sofifa.org/flags/60.png       90         90
# 24  https://cdn.sofifa.org/flags/27.png       89         89
# 34  https://cdn.sofifa.org/flags/21.png       88         88
# 35  https://cdn.sofifa.org/flags/54.png       88         88
#
#                  Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 8         Real Madrid  ...      82.0    87.0           92.0           91.0
# 12    Atlético Madrid  ...      82.0    90.0           89.0           89.0
# 24           Juventus  ...      84.0    93.0           93.0           90.0
# 34  FC Bayern München  ...      91.0    88.0           90.0           88.0
# 35        Real Madrid  ...      86.0    71.0           85.0           86.0
#
#    GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 8      11.0         8.0        9.0            7.0       11.0        €104.6M
# 12      6.0         8.0       15.0            5.0       15.0         €90.2M
# 24      3.0         3.0        2.0            4.0        3.0         €44.6M
# 34     15.0         6.0       10.0            5.0        6.0         €75.9M
# 35     12.0         5.0        5.0            5.0        9.0         €88.2M
#
# [5 rows x 89 columns]

# %%
#descriptive statistics of defenders
defenders.describe()
# Out:
#          Unnamed: 0             ID          Age      Overall    Potential  \
# count   5866.000000    5866.000000  5866.000000  5866.000000  5866.000000
# mean    8993.595465  213916.696727    25.474088    66.400102    71.011251
# std     5051.258641   28099.850029     4.517628     6.459210     5.814426
# min        8.000000     768.000000    16.000000    47.000000    52.000000
# 25%     4690.250000  199512.500000    22.000000    62.000000    67.000000
# 50%     9032.500000  220483.000000    25.000000    66.000000    71.000000
# 75%    13202.500000  235237.000000    29.000000    71.000000    75.000000
# max    18201.000000  246620.000000    41.000000    91.000000    92.000000
#
#           Special  International Reputation    Weak Foot  Skill Moves  \
# count  5866.00000               5866.000000  5866.000000  5866.000000
# mean   1610.70133                  1.099557     2.823048     2.211899
# std     203.29517                  0.359468     0.606912     0.429042
# min    1000.00000                  1.000000     1.000000     2.000000
# 25%    1459.00000                  1.000000     2.000000     2.000000
# 50%    1604.00000                  1.000000     3.000000     2.000000
# 75%    1753.00000                  1.000000     3.000000     2.000000
# max    2279.00000                  4.000000     5.000000     5.000000
#
#        Jersey Number  ...    Penalties    Composure      Marking  \
# count    5866.000000  ...  5866.000000  5866.000000  5866.000000
# mean       17.391067  ...    43.470167    58.414081    63.927890
# std        14.810695  ...    10.532063    10.033305     8.011463
# min         2.000000  ...    13.000000    29.000000    28.000000
# 25%         5.000000  ...    36.000000    51.250000    59.000000
# 50%        16.000000  ...    42.000000    59.000000    64.000000
# 75%        25.000000  ...    49.000000    66.000000    69.000000
# max        99.000000  ...    90.000000    91.000000    94.000000
#
#        StandingTackle  SlidingTackle     GKDiving   GKHandling    GKKicking  \
# count     5866.000000    5866.000000  5866.000000  5866.000000  5866.000000
# mean        66.727583      65.031879    10.545857    10.561712    10.524378
# std          7.044696       7.377843     3.066586     3.058959     3.172855
# min         27.000000      23.000000     1.000000     1.000000     1.000000
# 25%         62.000000      60.000000     8.000000     8.000000     8.000000
# 50%         66.000000      65.000000    10.000000    10.000000    11.000000
# 75%         71.000000      70.000000    13.000000    13.000000    13.000000
# max         93.000000      91.000000    32.000000    33.000000    41.000000
#
#        GKPositioning   GKReflexes
# count    5866.000000  5866.000000
# mean       10.545687    10.524719
# std         3.078298     3.074936
# min         1.000000     1.000000
# 25%         8.000000     8.000000
# 50%        11.000000    11.000000
# 75%        13.000000    13.000000
# max        32.000000    34.000000
#
# [8 rows x 44 columns]

# %%
total_defenders=defenders["Name"].count()
print("There are a total of",total_defenders,"players in the FIFA 19 dataset")
defenders_percentage=(total_defenders)/len(data["Name"])*100
print("The percentage of defenders is",defenders_percentage,"%")
# Out:
# There are a total of 5866 players in the FIFA 19 dataset
# The percentage of defenders is 32.21837754709727 %

# %%
old_DF=defenders.loc[defenders['Age'].idxmax()]
young_DF=defenders.loc[defenders["Age"].idxmin()]
best_DF=defenders.loc[defenders["Overall"].idxmax()]
print("The oldest defender is",defenders['Age'].max(),"years old",".","He is",old_DF["Name"],"from",old_DF["Nationality"], 
      "plays for",old_DF["Club"], "and has a rating of",old_DF["Overall"])
print("The youngest defender is",defenders['Age'].min(),"years old",".","He is",young_DF["Name"],"from",young_DF["Nationality"], 
      "plays for",young_DF["Club"], "and has a rating of",young_DF["Overall"])
print("The Best defender is",best_DF['Name'], "and has a rating of",best_DF["Overall"])
# Out:
# The oldest defender is 41 years old . He is H. Sulaimani from Saudi Arabia plays for Ohod Club and has a rating of 63
# The youngest defender is 16 years old . He is A. Doğan from Turkey plays for Kayserispor and has a rating of 55
# The Best defender is Sergio Ramos and has a rating of 91

# %% [markdown]
# # Midfielders

# %%
midfielders=['LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LDM','CDM', 'RDM']
midfielders=data.loc[data['Position'].isin(midfielders)]
midfielders.head()
# Out:
#     Unnamed: 0      ID          Name  Age  \
# 4            4  192985  K. De Bruyne   27
# 6            6  177003     L. Modrić   32
# 11          11  182521      T. Kroos   28
# 13          13  168542   David Silva   32
# 14          14  215914      N. Kanté   27
#
#                                              Photo Nationality  \
# 4   https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 13  https://cdn.sofifa.org/players/4/19/168542.png       Spain
# 14  https://cdn.sofifa.org/players/4/19/215914.png      France
#
#                                    Flag  Overall  Potential             Club  \
# 4    https://cdn.sofifa.org/flags/7.png       91         92  Manchester City
# 6   https://cdn.sofifa.org/flags/10.png       91         91      Real Madrid
# 11  https://cdn.sofifa.org/flags/21.png       90         90      Real Madrid
# 13  https://cdn.sofifa.org/flags/45.png       90         90  Manchester City
# 14  https://cdn.sofifa.org/flags/18.png       89         90          Chelsea
#
#     ... Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 4   ...      88.0    68.0           58.0           51.0     15.0        13.0
# 6   ...      84.0    60.0           76.0           73.0     13.0         9.0
# 11  ...      85.0    72.0           79.0           69.0     10.0        11.0
# 13  ...      93.0    59.0           53.0           29.0      6.0        15.0
# 14  ...      85.0    90.0           91.0           85.0     15.0        12.0
#
#     GKKicking  GKPositioning GKReflexes Release Clause
# 4         5.0           10.0       13.0        €196.4M
# 6         7.0           14.0        9.0        €137.4M
# 11       13.0            7.0       10.0        €156.8M
# 13        7.0            6.0       12.0          €111M
# 14       10.0            7.0       10.0        €121.3M
#
# [5 rows x 89 columns]

# %%
#descriptive statistics of defenders
midfielders.describe()
# Out:
#          Unnamed: 0             ID          Age      Overall    Potential  \
# count   6838.000000    6838.000000  6838.000000  6838.000000  6838.000000
# mean    8848.122550  215493.774349    24.778152    66.545774    71.787803
# std     5281.530296   28660.053921     4.510019     6.958003     6.214313
# min        4.000000      16.000000    16.000000    46.000000    48.000000
# 25%     4220.500000  202000.500000    21.000000    62.000000    67.000000
# 50%     8730.500000  222301.000000    24.000000    67.000000    71.000000
# 75%    13437.750000  236948.500000    28.000000    71.000000    76.000000
# max    18206.000000  246617.000000    41.000000    91.000000    95.000000
#
#            Special  International Reputation    Weak Foot  Skill Moves  \
# count  6838.000000               6838.000000  6838.000000  6838.000000
# mean   1731.137760                  1.118017     3.102662     2.724042
# std     178.466108                  0.398138     0.630270     0.629612
# min    1215.000000                  1.000000     1.000000     2.000000
# 25%    1604.000000                  1.000000     3.000000     2.000000
# 50%    1735.000000                  1.000000     3.000000     3.000000
# 75%    1855.000000                  1.000000     3.000000     3.000000
# max    2281.000000                  4.000000     5.000000     5.000000
#
#        Jersey Number  ...    Penalties    Composure      Marking  \
# count    6838.000000  ...  6838.000000  6838.000000  6838.000000
# mean       19.887979  ...    54.665399    61.775227    50.593302
# std        15.023935  ...    10.644744    10.001766    15.355530
# min         2.000000  ...    12.000000    31.000000    10.000000
# 25%        10.000000  ...    47.000000    55.000000    39.000000
# 50%        17.000000  ...    54.000000    62.000000    53.000000
# 75%        25.000000  ...    62.000000    69.000000    63.000000
# max        99.000000  ...    91.000000    93.000000    90.000000
#
#        StandingTackle  SlidingTackle     GKDiving   GKHandling    GKKicking  \
# count     6838.000000    6838.000000  6838.000000  6838.000000  6838.000000
# mean        51.362240      48.653992    10.489032    10.566540    10.559667
# std         16.579096      16.128766     3.113256     3.076263     3.125645
# min         10.000000      10.000000     1.000000     1.000000     1.000000
# 25%         38.000000      36.000000     8.000000     8.000000     8.000000
# 50%         54.000000      51.000000    10.000000    11.000000    11.000000
# 75%         65.000000      62.000000    13.000000    13.000000    13.000000
# max         91.000000      90.000000    37.000000    32.000000    41.000000
#
#        GKPositioning   GKReflexes
# count    6838.000000  6838.000000
# mean       10.554694    10.520181
# std         3.091956     3.103328
# min         1.000000     1.000000
# 25%         8.000000     8.000000
# 50%        11.000000    10.000000
# 75%        13.000000    13.000000
# max        30.000000    33.000000
#
# [8 rows x 44 columns]

# %%
old_MD=midfielders.loc[midfielders["Age"].idxmax()]
young_MD=midfielders.loc[midfielders["Age"].idxmin()]
print("The oldest midfielder is",midfielders["Age"].max(),"His name is",old_MD["Name"],"from",old_MD["Nationality"],"plays for",
     old_MD["Club"],"and has a rating of",old_MD["Overall"])
print("The youngest midfielder is",midfielders["Age"].min(),"His name is",young_MD["Name"],"from",young_MD["Nationality"],"plays for",
     young_MD["Club"],"and has a rating of",young_MD["Overall"])
# Out:
# The oldest midfielder is 41 His name is B. Nivet from France plays for ESTAC Troyes and has a rating of 71
# The youngest midfielder is 16 His name is Pelayo Morilla from Spain plays for Real Sporting de Gijón and has a rating of 63

# %%
total_midfielders=midfielders.Name.count()
midfielders_percentage=total_midfielders/len(data["Name"])*100
print("the percentage of midfielders is",midfielders_percentage,"%")
# Out:
# the percentage of midfielders is 37.55698357774482 %

# %% [markdown]
# # Strikers

# %%
strikers=['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW']
strikers=data[data["Position"].isin(strikers)]
strikers.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 5           5  183277          E. Hazard   27
# 7           7  176580          L. Suárez   31
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 5   https://cdn.sofifa.org/flags/7.png       91         91
# 7  https://cdn.sofifa.org/flags/60.png       91         91
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
#
# 75%        13.000000    13.000000
# max        33.000000    37.000000
#
# [8 rows x 44 columns]

# %%
total_strikers=strikers["Name"].count()
strikers_percentage=(total_strikers)/len(data["Name"])*100
print('There is a total of',total_strikers,"strikers in FIFA 19, with a percentage of", strikers_percentage,"%")
# Out:
# There is a total of 3418 strikers in FIFA 19, with a percentage of 18.772999395836766 %

# %%
plt.title("A Pie chart showing the percentage of the various positions")
positions=(goalkeepers_percentage,defenders_percentage,midfielders_percentage,strikers_percentage)
plt.pie(positions, labels=("goalkeepers", "defenders","midfielders","strikers"), autopct='%1.1f%%') 
plt.show()

# %%
fig, ax=plt.subplots(2,4,figsize=(20,6))

sns.distplot(goalkeepers['Age'], ax=ax[0,0]).set_title('Age Distribution of Goalkeepers')
sns.distplot(goalkeepers['Overall'], ax=ax[0,1]).set_title('Overall Rating Distribution of Goalkeepers')

sns.distplot(defenders['Age'], ax=ax[0,2]).set_title('Age Distribution of Defenders')
sns.distplot(defenders['Overall'], ax=ax[0,3]).set_title('Overall Rating Distribution of Defenders')

sns.distplot(midfielders['Age'], ax=ax[1,0]).set_title('Age Distribution of Mildfielders')
sns.distplot(midfielders['Overall'], ax=ax[1,1]).set_title('Overall Rating Distribution of Midfielders')

sns.distplot(strikers['Age'], ax=ax[1,2]).set_title('Age Distribution of Strikers')
sns.distplot(strikers['Age'], ax=ax[1,3]).set_title('Overall Rating Distribution of Strikers')
plt.tight_layout();

# %% [markdown]
# # ANALYSIS OF SOME SELECTED NATIONAL TEAMS

# %%
#looking at some of the powerhouse countries in world football 
countries=['England','Germany','Spain','Argentina','Brazil','Netherlands','Portugal','France','Italy','Uruguay','Belgium']
countries=data.loc[data["Nationality"].isin(countries)][['Name',"Nationality",'Age','Overall','Wage',"International Reputation"]]
countries.head()
# Out:
#                 Name Nationality  Age  Overall   Wage  \
# 0           L. Messi   Argentina   31       94  €565K
# 1  Cristiano Ronaldo    Portugal   33       94  €405K
# 2          Neymar Jr      Brazil   26       92  €290K
# 3             De Gea       Spain   27       91  €260K
# 4       K. De Bruyne     Belgium   27       91  €355K
#
#    International Reputation
# 0                       5.0
# 1                       5.0
# 2                       5.0
# 3                       4.0
# 4                       4.0

# %%
#looking at the distribution of wages of players in their countries to see which country's players have the highest wages
nationality=countries['Nationality']
wage=countries['Wage'].str.replace('[€,M,K]',"")
country_wage=wage.astype("int")
plt.title("Distrbution of wages of players by country")
plt.bar(nationality,country_wage.sort_values(ascending=False))
plt.xticks(rotation=60)
plt.show()

#distribution of players international reputation in their respected couuntries. some big national teams 
intl_reputation=countries["International Reputation"]
plt.bar(nationality,intl_reputation)
plt.title("Distribution of players international reputations by country")
plt.xticks(rotation=60)
plt.show()

#distribution of players overall ratings with respect to their countries
overall=countries["Overall"]
plt.title('distribution of players overall ratings by country')
plt.bar(nationality,overall)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # POPULAR AFRICAN NATIONAL TEAMS

# %%
#looking at some powerhouses of African countries
africa=["Ghana", 'Nigeria','Cameroon','Egypt','Ivory Coast','Senegal','Algeria','Morocco','Tunisia','South Africa','Mali']
africa=data.loc[data['Nationality'].isin(africa)]
africa.head()
# Out:
#     Unnamed: 0      ID          Name  Age  \
# 26          26  209331      M. Salah   26
# 44          44  201024  K. Koulibaly   27
# 58          58  208722       S. Mané   26
# 73          73  177509    M. Benatia   31
# 84          84  204485     R. Mahrez   27
#
#                                              Photo Nationality  \
# 26  https://cdn.sofifa.org/players/4/19/209331.png       Egypt
# 44  https://cdn.sofifa.org/players/4/19/201024.png     Senegal
# 58  https://cdn.sofifa.org/players/4/19/208722.png     Senegal
# 73  https://cdn.sofifa.org/players/4/19/177509.png     Morocco
# 84  https://cdn.sofifa.org/players/4/19/204485.png     Algeria
#
#                                     Flag  Overall  Potential             Club  \
# 26  https://cdn.sofifa.org/flags/111.png       88         89        Liverpool
# 44  https://cdn.sofifa.org/flags/136.png       87         90           Napoli
# 58  https://cdn.sofifa.org/flags/136.png       86         87        Liverpool
# 73  https://cdn.sofifa.org/flags/129.png       86         86         Juventus
# 84   https://cdn.sofifa.org/flags/97.png       85         85  Manchester City
#
#     ... Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 26  ...      91.0    38.0           43.0           41.0     14.0        14.0
# 44  ...      78.0    91.0           88.0           86.0      7.0        11.0
# 58  ...      80.0    42.0           42.0           38.0     10.0        10.0
# 73  ...      82.0    89.0           87.0           85.0      7.0         4.0
# 84  ...      86.0    45.0           31.0           18.0     15.0         9.0
#
#     GKKicking  GKPositioning GKReflexes Release Clause
# 26        9.0           11.0       14.0        €137.3M
# 44        7.0           13.0        5.0         €90.5M
# 58       15.0            7.0       14.0        €102.7M
# 73        8.0            7.0       11.0         €49.5M
# 84       13.0           11.0        6.0         €74.9M
#
# [5 rows x 89 columns]

# %%
africa.shape
# Out:
# (877, 89)

# %%
africa.describe()
# Out:
#          Unnamed: 0             ID         Age     Overall   Potential  \
# count    877.000000     877.000000  877.000000  877.000000  877.000000
# mean    7269.259977  216843.009122   25.039909   68.468643   73.039909
# std     4684.336621   24142.069731    4.057746    5.820212    5.511466
# min       26.000000   49659.000000   16.000000   48.000000   58.000000
# 25%     3239.000000  202620.000000   22.000000   65.000000   69.000000
# 50%     6588.000000  221641.000000   25.000000   69.000000   73.000000
# 75%    10708.000000  236454.000000   28.000000   72.000000   77.000000
# max    18174.000000  246307.000000   36.000000   88.000000   90.000000
#
#            Special  International Reputation   Weak Foot  Skill Moves  \
# count   877.000000                877.000000  877.000000   877.000000
# mean   1680.648803                  1.137970    3.006842     2.636260
# std     222.914054                  0.408675    0.663771     0.736342
# min     752.000000                  1.000000    1.000000     1.000000
# 25%    1568.000000                  1.000000    3.000000     2.000000
# 50%    1701.000000                  1.000000    3.000000     3.000000
# 75%    1826.000000                  1.000000    3.000000     3.000000
# max    2168.000000                  3.000000    5.000000     5.000000
#
#        Jersey Number  ...   Penalties   Composure     Marking  StandingTackle  \
# count     877.000000  ...  877.000000  877.000000  877.000000      877.000000
# mean       20.521095  ...   52.034208   61.988597   48.118586       48.941847
# std        17.442104  ...   13.993678   10.249395   19.926224       21.824435
# min         1.000000  ...    9.000000   13.000000    8.000000        8.000000
# 25%         9.000000  ...   43.000000   56.000000   30.000000       29.000000
# 50%        18.000000  ...   53.000000   63.000000   53.000000       55.000000
# 75%        26.000000  ...   63.000000   69.000000   66.000000       68.000000
# max        99.000000  ...   90.000000   91.000000   91.000000       90.000000
#
#        SlidingTackle    GKDiving  GKHandling   GKKicking  GKPositioning  \
# count     877.000000  877.000000  877.000000  877.000000     877.000000
# mean       46.251995   13.579247   13.324971   13.286203      13.380844
# std        21.604564   13.191068   12.510378   12.273666      12.429564
# min         8.000000    1.000000    1.000000    1.000000       1.000000
# 25%        25.000000    8.000000    8.000000    8.000000       8.000000
# 50%        52.000000   11.000000   11.000000   11.000000      11.000000
# 75%        65.000000   14.000000   13.000000   14.000000      14.000000
# max        86.000000   83.000000   79.000000   85.000000      77.000000
#
#        GKReflexes
# count  877.000000
# mean    13.553022
# std     13.374513
# min      1.000000
# 25%      8.000000
# 50%     11.000000
# 75%     14.000000
# max     80.000000
#
# [8 rows x 44 columns]

# %%
#looking at the number of players in each of the selected African countries
more=africa['Nationality'].value_counts()
more
# Out:
# Senegal         130
# Nigeria         121
# Ghana           114
# Ivory Coast     100
# Cameroon         90
# Morocco          85
# South Africa     71
# Algeria          60
# Mali             43
# Tunisia          32
# Egypt            31
# Name: Nationality, dtype: int64

# %%
#looking at which African country's players have the highest wage
wage=africa['Wage'].str.replace('[€,M,K]',"")
africa_wage=wage.astype("int")
nation=africa['Nationality']
plt.title("Distribution of African player wages with respect to national teams")
plt.bar(nation,africa_wage.sort_values(ascending=False))
plt.xticks(rotation=60)
plt.show()

# %%
#looking at which African country has the highest overall rating 
overall=africa['Overall']
nations=africa['Nationality']
plt.title('Distribution of African players overall rating with respect to their countries')
plt.bar(nations,overall)
plt.xlabel('African countries')
plt.ylabel("Overall Ratings of players")
plt.xticks(rotation=60)
plt.show()

# %%
#looking at the best players in Africa with respect to their positions
africa.loc[africa.groupby(africa['Position'])["Overall"].idxmax()][['Name','Position','Age','Nationality','Club','Overall']]
# Out:
#                Name Position  Age  Nationality                    Club  \
# 507    R. Boudebouz      CAM   28      Algeria              Real Betis
# 73       M. Benatia       CB   31      Morocco                Juventus
# 249       T. Partey      CDM   25        Ghana         Atlético Madrid
# 11435      M. Dauda       CF   20        Ghana          RSC Anderlecht
# 391      K. Boateng       CM   31        Ghana                Sassuolo
# 426        A. Onana       GK   22     Cameroon                    Ajax
# 358      F. Ghoulam       LB   27      Algeria                  Napoli
# 44     K. Koulibaly      LCB   27      Senegal                  Napoli
# 559        A. Harit      LCM   21      Morocco           FC Schalke 04
# 331         J. Seri      LDM   26  Ivory Coast                  Fulham
# 58          S. Mané       LM   26      Senegal               Liverpool
# 270         W. Zaha       LS   25  Ivory Coast          Crystal Palace
# 856       M. Gradel       LW   30  Ivory Coast  Toulouse Football Club
# 2441      A. Oyongo      LWB   27     Cameroon         Montpellier HSC
# 171       H. Ziyech      RAM   25      Morocco                    Ajax
# 482       S. Aurier       RB   25  Ivory Coast       Tottenham Hotspur
# 635        A. Mandi      RCB   26      Algeria              Real Betis
# 594       J. Gbamin      RCM   22  Ivory Coast         1. FSV Mainz 05
# 198        I. Gueye      RDM   28      Senegal                 Everton
# 26         M. Salah       RM   26        Egypt               Liverpool
# 423       M. Marega       RS   27         Mali                FC Porto
# 84        R. Mahrez       RW   27      Algeria         Manchester City
# 2398        A. Nyom      RWB   30     Cameroon              CD Leganés
# 480    V. Aboubakar       ST   26     Cameroon                FC Porto
#
#        Overall
# 507         80
# 73          86
# 249         82
# 11435       64
# 391         81
# 426         80
# 358         81
# 44          87
# 559         79
# 331         81
# 58          86
# 270         82
# 856         78
# 2441        74
# 171         83
# 482         80
# 635         79
# 594         79
# 198         83
# 26          88
# 423         80
# 84          85
# 2398        74
# 480         80

# %%
#looking at the overall best player in Africa
best=africa.loc[africa['Overall'].idxmax()]
#looking at the oldest and the youngest player in Africa
oldest=africa.loc[africa["Age"].idxmax()]
young=africa.loc[africa.Age.idxmin()]
print('The best player in Africa has an ooverall rating of',best['Overall'].max(),".", 'His name is',best['Name'],'from',
     best['Nationality'], 'and plays for',best['Club'])
print('The oldest player in Africa is',oldest['Age'].max(),".", 'His name is',oldest['Name'],'from',
     oldest['Nationality'], 'and plays for',oldest['Club'])
print('The youngest player in Africa is',young['Age'].min(),".", 'His name is',young['Name'],'from',
     young['Nationality'], 'and plays for',young['Club'])
# Out:
# The best player in Africa has an ooverall rating of 88 . His name is M. Salah from Egypt and plays for Liverpool
# The oldest player in Africa is 36 . His name is K. Fegrouche from Morocco and plays for IK Sirius
# The youngest player in Africa is 16 . His name is A. Mahlonoko from South Africa and plays for Orlando Pirates

# %%
#looking at the worst players in Africa with their respective position
africa.loc[africa.groupby(africa['Position'])["Overall"].idxmin()][['Name','Position','Age','Nationality','Club','Overall']]
# Out:
#                  Name Position  Age   Nationality                Club  Overall
# 17808    A. Mahlonoko      CAM   16  South Africa     Orlando Pirates       52
# 17219     P. Bahanack       CB   20      Cameroon      Stade de Reims       55
# 15958       R. Acquah      CDM   21         Ghana           LASK Linz       58
# 15621        M. Kudus       CF   17         Ghana     FC Nordsjælland       59
# 18174      S. Adewusi       CM   18       Nigeria     Carlisle United       48
# 17920        D. Thiam       GK   20       Senegal                SPAL       51
# 16992        L. Mirwa       LB   23  South Africa       Kaizer Chiefs       56
# 15271       E. Monthe      LCB   23      Cameroon     Tranmere Rovers       60
# 14965     M. Ashimeru      LCM   20         Ghana       FC St. Gallen       60
# 8946     S. N'Guessan      LDM   23   Ivory Coast   AS Nancy Lorraine       66
# 17160        H. Offia       LM   18       Nigeria           IK Sirius       55
# 14649  F. Okenabirhie       LS   22       Nigeria          Shrewsbury       61
# 15814       I. Mensah       LW   23         Ghana            IK Start       59
# 15895        C. Antwi      LWB   18         Ghana     FC Nordsjælland       58
# 171         H. Ziyech      RAM   25       Morocco                Ajax       83
# 16328       O. Mbaizo       RB   20      Cameroon  Philadelphia Union       57
# 14277       F. Obilor      RCB   27       Nigeria        HJK Helsinki       61
# 15277         C. Zock      RCM   24      Cameroon             FC Sion       60
# 6753         Y. Eteki      RDM   20      Cameroon          UD Almería       68
# 15556        E. Opoku       RM   20         Ghana    Columbus Crew SC       59
# 12619      I. Akinade       RS   24       Nigeria        Waterford FC       63
# 17318        I. Sadiq       RW   18         Ghana     FC Nordsjælland       54
# 10875         M. Dube      RWB   25  South Africa     Orlando Pirates       65
# 17096       J. Kayode       ST   18       Nigeria    Rotherham United       55

# %% [markdown]
# # GHANAIAN PLAYERS ANALYSIS

# %%
Ghana=data.loc[data["Nationality"]=="Ghana"]
Ghana.head()
# Out:
#       Unnamed: 0      ID           Name  Age  \
# 249          249  209989      T. Partey   25
# 391          391  173909     K. Boateng   31
# 679          679  186832     K. Asamoah   29
# 1118        1118  176571        A. Ayew   28
# 1226        1226  213013  F. Acheampong   24
#
#                                                Photo Nationality  \
# 249   https://cdn.sofifa.org/players/4/19/209989.png       Ghana
# 391   https://cdn.sofifa.org/players/4/19/173909.png       Ghana
# 679   https://cdn.sofifa.org/players/4/19/186832.png       Ghana
# 1118  https://cdn.sofifa.org/players/4/19/176571.png       Ghana
# 1226  https://cdn.sofifa.org/players/4/19/213013.png       Ghana
#
#                                       Flag  Overall  Potential  \
# 249   https://cdn.sofifa.org/flags/117.png       82         88
# 391   https://cdn.sofifa.org/flags/117.png       81         81
# 679   https://cdn.sofifa.org/flags/117.png       79         79
# 1118  https://cdn.sofifa.org/flags/117.png       77         77
# 1226  https://cdn.sofifa.org/flags/117.png       76         81
#
#                  Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 249   Atlético Madrid  ...      75.0    80.0           83.0           80.0
# 391          Sassuolo  ...      82.0    59.0           78.0           74.0
# 679             Inter  ...      76.0    80.0           78.0           80.0
# 1118    Fenerbahçe SK  ...      74.0    49.0           60.0           57.0
# 1226  Tianjin TEDA FC  ...      67.0    42.0           62.0           52.0
#
#      GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 249      11.0        13.0        9.0            9.0        7.0         €57.4M
# 391       6.0        11.0       15.0           16.0        6.0         €25.5M
# 679       5.0         4.0        3.0            4.0        5.0         €16.2M
# 1118     10.0         6.0       12.0            7.0       15.0            NaN
# 1226     14.0         9.0       10.0           16.0       13.0         €23.4M
#
# [5 rows x 89 columns]

# %%
Gh=Ghana["Name"].count()
print("There are", Gh, "Ghanaian players in the dataset")
# Out:
# There are 114 Ghanaian players in the dataset

# %%
Ghana.describe()
# Out:
#          Unnamed: 0             ID         Age     Overall   Potential  \
# count    114.000000     114.000000  114.000000  114.000000  114.000000
# mean    8409.842105  219986.043860   23.657895   67.043860   73.087719
# std     5119.178530   20969.611443    3.625936    6.185038    4.944938
# min      249.000000  158375.000000   17.000000   51.000000   61.000000
# 25%     3823.000000  206594.750000   21.000000   63.000000   70.000000
# 50%     8170.500000  224266.500000   23.000000   67.000000   73.000000
# 75%    12823.500000  237198.750000   26.000000   72.000000   76.000000
# max    18014.000000  245857.000000   33.000000   82.000000   88.000000
#
#            Special  International Reputation   Weak Foot  Skill Moves  \
# count   114.000000                114.000000  114.000000   114.000000
# mean   1695.728070                  1.114035    2.947368     2.640351
# std     231.609195                  0.393729    0.738836     0.692912
# min     752.000000                  1.000000    1.000000     1.000000
# 25%    1562.250000                  1.000000    2.250000     2.000000
# 50%    1697.500000                  1.000000    3.000000     3.000000
# 75%    1829.500000                  1.000000    3.000000     3.000000
# max    2168.000000                  3.000000    5.000000     4.000000
#
#        Jersey Number  ...   Penalties   Composure     Marking  StandingTackle  \
# count     114.000000  ...  114.000000  114.000000  114.000000      114.000000
# mean       21.324561  ...   50.333333   60.517544   48.412281       49.649123
# std        15.637767  ...   12.481254   10.348983   18.841120       21.077179
# min         2.000000  ...   12.000000   23.000000    8.000000       11.000000
# 25%        11.000000  ...   42.000000   54.000000   33.000000       30.250000
# 50%        20.000000  ...   50.000000   62.000000   52.000000       56.000000
# 75%        27.750000  ...   60.750000   68.000000   64.000000       68.000000
# max        99.000000  ...   74.000000   82.000000   82.000000       83.000000
#
#        SlidingTackle    GKDiving  GKHandling   GKKicking  GKPositioning  \
# count     114.000000  114.000000  114.000000  114.000000     114.000000
# mean       47.175439   12.350877   11.289474   11.508772      11.982456
# std        20.133293    9.735422    9.214959    8.564431       9.049502
# min        11.000000    1.000000    1.000000    1.000000       1.000000
# 25%        30.000000    8.000000    7.250000    7.000000       8.000000
# 50%        48.000000   11.000000   10.000000   10.000000      10.500000
# 75%        65.000000   14.000000   12.750000   13.000000      13.000000
# max        80.000000   66.000000   70.000000   67.000000      66.000000
#
#        GKReflexes
# count  114.000000
# mean    12.175439
# std     10.221655
# min      1.000000
# 25%      8.000000
# 50%     11.000000
# 75%     13.000000
# max     69.000000
#
# [8 rows x 44 columns]

# %%
oldest=Ghana.loc[Ghana['Age'].idxmax()]
youngest=Ghana.loc[Ghana["Age"].idxmin()]
best=Ghana.loc[Ghana["Overall"].idxmax()]
worst=Ghana.loc[Ghana["Overall"].idxmin()]
fast=Ghana.loc[Ghana["SprintSpeed"].idxmax()]
slow=Ghana.loc[Ghana["SprintSpeed"].idxmin()]
dribbler=Ghana.loc[Ghana["Dribbling"].idxmax()]
volley=Ghana.loc[Ghana["Volleys"].idxmax()]
jump=Ghana.loc[Ghana["Jumping"].idxmax()]
penalty=Ghana.loc[Ghana["Penalties"].idxmax()]
worst_p=Ghana.loc[Ghana["Penalties"].idxmin()]
intercept=Ghana.loc[Ghana["Interceptions"].idxmax()]
aggresive=Ghana.loc[Ghana["Aggression"].idxmax()]
vision=Ghana.loc[Ghana["Vision"].idxmax()]
GK=Ghana.loc[Ghana["GKReflexes"].idxmax()]
Gk_dive=Ghana.loc[Ghana["GKDiving"].idxmax()]
intl_repute=Ghana.loc[Ghana["International Reputation"].idxmax()]
agility=Ghana.loc[Ghana["Agility"].idxmax()]
stamina=Ghana.loc[Ghana["Stamina"].idxmax()]
control=Ghana.loc[Ghana["BallControl"].idxmax()]
shot=Ghana.loc[Ghana["ShotPower"].idxmax()]
acceleration=Ghana.loc[Ghana["Acceleration"].idxmax()]
marking=Ghana.loc[Ghana["Marking"].idxmax()]
long_passing=data.loc[Ghana["LongPassing"].idxmax()]
free_kick=Ghana.loc[Ghana["FKAccuracy"].idxmax()]
finish=Ghana.loc[Ghana["Finishing"].idxmax()]
print("the oldest player is",Ghana["Age"].max(),"years","." "His name is", oldest["Name"], "from", oldest["Nationality"], "and plays for", 
      oldest["Club"])
print("the youngest player is",Ghana["Age"].min(),"." "His name is", youngest["Name"], "from", youngest["Nationality"],
      "and plays for", youngest["Club"])
print("the best player has an overall rating of",Ghana["Overall"].max(),"." "His name is", best["Name"], "from", best["Nationality"],
      "and plays for", best["Club"])
print("The worst player has an overall rating of", Ghana["Overall"].min(),".", "His name is", worst["Name"], "from",
     worst["Nationality"], "and plays for", worst["Club"])
print("The most fastest player has a sprint speed of", Ghana["SprintSpeed"].max(),".", "His name is", fast["Name"], "from",
     fast["Nationality"], "and plays for", fast["Club"])
print("The most slowest player has a sprint speed of", Ghana["SprintSpeed"].min(),".", "His name is", slow["Name"], "from",
     slow["Nationality"], "and plays for", slow["Club"])
print("The best dribbler has a dribbling ability of", Ghana["Dribbling"].max(),".", "His name is", dribbler["Name"], "from",
     dribbler["Nationality"], "and plays for", dribbler["Club"])
print("The player who plays volley more than anyone has a Volley play ability of", Ghana["Volleys"].max(),".", "His name is",
      volley["Name"], "from",volley["Nationality"], "and plays for", volley["Club"])
print("The player with the best jump has a jumping rate of", Ghana["Jumping"].max(),".", "His name is", jump["Name"], "from",
     jump["Nationality"], "and plays for", jump["Club"])
print("The best penalty taker has a penalty taking ability of", Ghana["Penalties"].max(),".", "His name is", penalty["Name"],
      "from",penalty["Nationality"], "and plays for", penalty["Club"])
print("The worst penalty taker has a penalty taking ability of", Ghana["Penalties"].min(),".", "His name is", worst_p["Name"],
      "from",worst_p["Nationality"], "and plays for", worst_p["Club"])
print("The most aggressive player has a aggresive ability of", Ghana["Aggression"].max(),".", "His name is", aggresive["Name"],
      "from", aggresive["Nationality"], "and plays for", aggresive["Club"])
print("The player with the best interception has an intercepting ability of", Ghana["Interceptions"].max(),".", "His name is",
      intercept["Name"], "from",intercept["Nationality"], "and plays for", intercept["Club"])
print("The player with the best vision has a vision ability of", Ghana["Vision"].max(),".", "His name is", vision["Name"], 
      "from",vision["Nationality"], "and plays for", vision["Club"])
print("The goalkeeper with good reflexes has a reflex ability of", Ghana["GKReflexes"].max(),".", "His name is", GK["Name"], 
      "from", GK["Nationality"], "and plays for", GK["Club"])
print("The player with high international reputation has an international rating of ", Ghana["International Reputation"].max(),".",
      "His name is", intl_repute["Name"], "from",intl_repute["Nationality"], "and plays for", intl_repute["Club"])
print("The goalkeeper with the highest diving ability has a diving ability of", Ghana["GKDiving"].max(),".", "His name is", 
      Gk_dive["Name"], "from",Gk_dive["Nationality"], "and plays for", Gk_dive["Club"])
print("The player with the highest agility has agility rating of", Ghana["Agility"].max(),".", "His name is", 
      agility["Name"], "from",agility["Nationality"], "and plays for", agility["Club"])
print("The player with the highest stamina has a stamina rating of", Ghana["Stamina"].max(),".", "His name is", 
      stamina["Name"], "from",stamina["Nationality"], "and plays for", stamina["Club"])
print("The best controller of the ball has a ball control rate of", Ghana["BallControl"].max(),".", "His name is", 
      control["Name"], "from",control["Nationality"], "and plays for", control["Club"])
print("The player with the most powerful shot has a shooting power of", Ghana["ShotPower"].max(),".", "His name is", 
      shot["Name"], "from",shot["Nationality"], "and plays for", shot["Club"])
print("The player with the highest acceleration has an acceleration rating of", Ghana["Acceleration"].max(),".", "His name is", 
      acceleration["Name"], "from",acceleration["Nationality"], "and plays for", acceleration["Club"])
print("The player who marks very well has a marking rating of", Ghana["Marking"].max(),".", "His name is", 
      marking["Name"], "from",marking["Nationality"], "and plays for", marking["Club"])
print("The best freekick taker has an accuracy of", Ghana["FKAccuracy"].max(),".", "His name is", 
      free_kick["Name"], "from",free_kick["Nationality"], "and plays for", free_kick["Club"])
print("The best long ball passer of the ball has a passing accuracy of", Ghana["LongPassing"].max(),".", "His name is", 
      long_passing["Name"], "from",long_passing["Nationality"], "and plays for", long_passing["Club"])
print("The best finisher has a finishing rating of", Ghana["Finishing"].max(),".", "His name is", 
      finish["Name"], "from",finish["Nationality"], "and plays for", finish["Club"])
# Out:
# the oldest player is 33 years .His name is B. Kumordzi from Ghana and plays for KV Kortrijk
# the youngest player is 17 .His name is M. Kudus from Ghana and plays for FC Nordsjælland
# the best player has an overall rating of 82 .His name is T. Partey from Ghana and plays for Atlético Madrid
# The worst player has an overall rating of 51 . His name is C. Addai from Ghana and plays for Coventry City
# The most fastest player has a sprint speed of 94.0 . His name is F. Acheampong from Ghana and plays for Tianjin TEDA FC
# The most slowest player has a sprint speed of 22.0 . His name is C. Addai from Ghana and plays for Coventry City
# The best dribbler has a dribbling ability of 82.0 . His name is K. Asamoah from Ghana and plays for Inter
# The player who plays volley more than anyone has a Volley play ability of 83.0 . His name is K. Boateng from Ghana and plays for Sassuolo
# The player with the best jump has a jumping rate of 92.0 . His name is E. Boateng from Ghana and plays for Levante UD
# The best penalty taker has a penalty taking ability of 74.0 . His name is J. Ayew from Ghana and plays for Crystal Palace
# The worst penalty taker has a penalty taking ability of 12.0 . His name is C. Addai from Ghana and plays for Coventry City
# The most aggressive player has a aggresive ability of 90.0 . His name is J. Aidoo from Ghana and plays for KRC Genk
# The player with the best interception has an intercepting ability of 80.0 . His name is N. Asare from Ghana and plays for KAA Gent
# The player with the best vision has a vision ability of 78.0 . His name is K. Boateng from Ghana and plays for Sassuolo
# The goalkeeper with good reflexes has a reflex ability of 69.0 . His name is A. Kwarasey from Ghana and plays for Vålerenga Fotball
# The player with high international reputation has an international rating of  3.0 . His name is K. Boateng from Ghana and plays for Sassuolo
# The goalkeeper with the highest diving ability has a diving ability of 66.0 . His name is A. Kwarasey from Ghana and plays for Vålerenga Fotball
# The player with the highest agility has agility rating of 93.0 . His name is F. Acheampong from Ghana and plays for Tianjin TEDA FC
# The player with the highest stamina has a stamina rating of 93.0 . His name is M. Odjer from Ghana and plays for US Salernitana 1919
# The best controller of the ball has a ball control rate of 84.0 . His name is K. Boateng from Ghana and plays for Sassuolo
# The player with the most powerful shot has a shooting power of 85.0 . His name is M. Wakaso from Ghana and plays for Deportivo Alavés
# The player with the highest acceleration has an acceleration rating of 92.0 . His name is F. Acheampong from Ghana and plays for Tianjin TEDA FC
# The player who marks very well has a marking rating of 82.0 . His name is G. Donsah from Ghana and plays for Bologna
# The best freekick taker has an accuracy of 71.0 . His name is K. Boateng from Ghana and plays for Sassuolo
# The best long ball passer of the ball has a passing accuracy of 79.0 . His name is T. Partey from Ghana and plays for Atlético Madrid
# The best finisher has a finishing rating of 78.0 . His name is K. Boateng from Ghana and plays for Sassuolo

# %%
total_players=Ghana["Name"].count()
print("There are",total_players,"players in Ghana from the FIFA 19 dataset")
# Out:
# There are 114 players in Ghana from the FIFA 19 dataset

# %% [markdown]
# # AGE DISTRIBUTION OF GHANAIAN PLAYERS

# %%
agegh=Ghana["Age"]
age=Ghana.Age
plt.title("age distribution of Ghanaian players")
plt.hist(agegh)
plt.xlabel("Age")
plt.ylabel("Number of players")
plt.show()
print("the average age of Ghanaian players on FIFA 19 is ", np.mean(Ghana["Age"]))
# Out:
# the average age of Ghanaian players on FIFA 19 is  23.657894736842106

# %% [markdown]
# # ANALYSIS BASED ON LEAGUE

# %% [markdown]
# # 1. THE ENGLISH PREMEIR LEAGUE

# %%
EPL=["Chelsea", "Manchester United", "Manchester City", "Everton", "Tottenham Hotspur","Liverpool","Arsenal",
         "Wolverhampton Wanderers","Brighton & Hove Albion", "Crystal Palace",'Sheffield United', "Fulham", 
   "West Bromwich Albion", "Burnley", "Leeds United", "West Ham United", "Newcastle United", "Leicester City", "Aston Villa",
     "Southampton" ]
EPL=data.loc[data["Club"].isin(EPL)]
EPL
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 3               3  193080          De Gea   27
# 4               4  192985    K. De Bruyne   27
# 5               5  183277       E. Hazard   27
# 13             13  168542     David Silva   32
# 14             14  215914        N. Kanté   27
# ...           ...     ...             ...  ...
# 17503       17503  236009         C. John   18
# 17519       17519  242422      J. Doherty   17
# 17677       17677  246454        D. Revan   17
# 17708       17708  240603  J. Doyle-Hayes   19
# 17795       17795  245611    D. Parkhouse   18
#
#                                                 Photo          Nationality  \
# 3      https://cdn.sofifa.org/players/4/19/193080.png                Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png              Belgium
# 5      https://cdn.sofifa.org/players/4/19/183277.png              Belgium
# 13     https://cdn.sofifa.org/players/4/19/168542.png                Spain
# 14     https://cdn.sofifa.org/players/4/19/215914.png               France
# ...                                               ...                  ...
# 17503  https://cdn.sofifa.org/players/4/19/236009.png              England
# 17519  https://cdn.sofifa.org/players/4/19/242422.png  Republic of Ireland
# 17677  https://cdn.sofifa.org/players/4/19/246454.png              England
# 17708  https://cdn.sofifa.org/players/4/19/240603.png  Republic of Ireland
# 17795  https://cdn.sofifa.org/players/4/19/245611.png     Northern Ireland
#
#                                       Flag  Overall  Potential  \
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# 5       https://cdn.sofifa.org/flags/7.png       91         91
# 13     https://cdn.sofifa.org/flags/45.png       90         90
# 14     https://cdn.sofifa.org/flags/18.png       89         90
# ...                                    ...      ...        ...
# 17503  https://cdn.sofifa.org/flags/14.png       54         72
# 17519  https://cdn.sofifa.org/flags/25.png       54         74
# 17677  https://cdn.sofifa.org/flags/14.png       53         72
# 17708  https://cdn.sofifa.org/flags/25.png       53         72
# 17795  https://cdn.sofifa.org/flags/35.png       52         71
#
#                           Club  ... Composure Marking StandingTackle  \
# 3            Manchester United  ...      68.0    15.0           21.0
# 4              Manchester City  ...      88.0    68.0           58.0
# 5                      Chelsea  ...      91.0    34.0           27.0
# 13             Manchester City  ...      93.0    59.0           53.0
# 14                     Chelsea  ...      85.0    90.0           91.0
# ...                        ...  ...       ...     ...            ...
# 17503  Wolverhampton Wanderers  ...      49.0    49.0           51.0
# 17519         Sheffield United  ...      38.0    57.0           58.0
# 17677              Aston Villa  ...      39.0    49.0           56.0
# 17708              Aston Villa  ...      43.0    44.0           46.0
# 17795         Sheffield United  ...      46.0    21.0           20.0
#
#        SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning  \
# 3               13.0     90.0        85.0       87.0           88.0
# 4               51.0     15.0        13.0        5.0           10.0
# 5               22.0     11.0        12.0        6.0            8.0
# 13              29.0      6.0        15.0        7.0            6.0
# 14              85.0     15.0        12.0       10.0            7.0
# ...              ...      ...         ...        ...            ...
# 17503           50.0     13.0         9.0        7.0            8.0
# 17519           55.0     11.0         9.0        7.0            9.0
# 17677           56.0      8.0        14.0        8.0            7.0
# 17708           48.0      8.0        10.0        6.0           10.0
# 17795           22.0     11.0        12.0       11.0            6.0
#
#       GKReflexes Release Clause
# 3           94.0        €138.6M
# 4           13.0        €196.4M
# 5            8.0        €172.1M
# 13          12.0          €111M
# 14          10.0        €121.3M
# ...          ...            ...
# 17503        8.0          €328K
# 17519        6.0          €348K
# 17677       14.0          €278K
# 17708        7.0          €328K
# 17795       12.0          €253K
#
# [643 rows x 89 columns]

# %%
EPL["Club"].value_counts()
# Out:
# Everton                    33
# Manchester City            33
# Tottenham Hotspur          33
# Burnley                    33
# Manchester United          33
# Chelsea                    33
# Newcastle United           33
# Southampton                33
# Liverpool                  33
# Wolverhampton Wanderers    33
# Arsenal                    33
# Crystal Palace             32
# Brighton & Hove Albion     32
# Leicester City             32
# Fulham                     32
# West Ham United            32
# West Bromwich Albion       30
# Leeds United               30
# Sheffield United           30
# Aston Villa                30
# Name: Club, dtype: int64

# %%
#number of different nationalities in the EPL
epl=EPL["Nationality"].value_counts()
epl
# Out:
# England                260
# Spain                   35
# Republic of Ireland     30
# France                  26
# Scotland                24
#                       ...
# Armenia                  1
# Finland                  1
# Bosnia Herzegovina       1
# Uruguay                  1
# Equatorial Guinea        1
# Name: Nationality, Length: 66, dtype: int64

# %%
epl_intl=epl.count()
print("There are", epl_intl, "countries whose players plays in the EPL")
# Out:
# There are 66 countries whose players plays in the EPL

# %%
total_epl=EPL["Name"].count()
total_clubs=EPL["Club"].unique()
average_players=(total_epl)/len(total_clubs)
print("There are a total of", total_epl,"players in the EPL",".","on average there are",average_players,"in each team in the EPL")
# Out:
# There are a total of 643 players in the EPL . on average there are 32.15 in each team in the EPL

# %%
#looking the the statistical relationship of the various features of epl players
EPL[['Age','Crossing', 'International Reputation',
       'Skill Moves', 'Work Rate', 'Body Type','Overall', 'Potential', 'Value', 'Wage',
       'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
       'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']].corr()
# Out:
#                                Age  Crossing  International Reputation  \
# Age                       1.000000  0.173776                  0.480834
# Crossing                  0.173776  1.000000                  0.294863
# International Reputation  0.480834  0.294863                  1.000000
# Skill Moves              -0.011463  0.783824                  0.226370
# Overall                   0.603620  0.427567                  0.681455
# Potential                -0.111241  0.262304                  0.463982
# Finishing                 0.066050  0.723601                  0.275206
# HeadingAccuracy           0.131897  0.522609                  0.210930
# ShortPassing              0.202183  0.825434                  0.374764
# Volleys                   0.156288  0.748273                  0.346139
# Dribbling                 0.020814  0.889006                  0.244123
# Curve                     0.143995  0.895305                  0.305537
# FKAccuracy                0.153769  0.789026                  0.310260
# LongPassing               0.272346  0.751949                  0.383865
# BallControl               0.136304  0.872818                  0.323675
# Acceleration             -0.193604  0.618758                  0.074862
# SprintSpeed              -0.185080  0.610835                  0.088356
# Agility                  -0.032565  0.693653                  0.157409
# Reactions                 0.607095  0.449931                  0.651403
# Balance                  -0.071160  0.639062                  0.077547
# ShotPower                 0.162834  0.791472                  0.325171
# Jumping                   0.327092  0.118396                  0.202349
# Stamina                   0.109725  0.775892                  0.232461
# Strength                  0.354894  0.083495                  0.236787
# LongShots                 0.145816  0.814141                  0.315458
# Aggression                0.262979  0.550947                  0.256952
# Interceptions             0.230376  0.460780                  0.201848
# Positioning               0.088293  0.841151                  0.270722
# Vision                    0.283754  0.744903                  0.447052
# Penalties                 0.146539  0.691970                  0.333049
# Composure                 0.477483  0.658124                  0.577407
# Marking                   0.166443  0.467476                  0.153539
# StandingTackle            0.144521  0.465996                  0.133790
# SlidingTackle             0.123746  0.426824                  0.107550
# GKDiving                  0.206979 -0.668291                  0.025684
# GKHandling                0.211829 -0.664547                  0.032030
# GKKicking                 0.209053 -0.655524                  0.027483
# GKPositioning             0.217040 -0.661655                  0.032608
# GKReflexes                0.192681 -0.664584                  0.027957
#
#                           Skill Moves   Overall  Potential  Finishing  \
# Age                         -0.011463  0.603620  -0.111241   0.066050
# Crossing                     0.783824  0.427567   0.262304   0.723601
# International Reputation     0.226370  0.681455   0.463982   0.275206
# Skill Moves                  1.000000  0.308577   0.312150   0.791433
# Overall                      0.308577  1.000000   0.641978   0.336765
# Potential                    0.312150  0.641978   1.000000   0.283360
# BallControl                   -0.757487   -0.759733
# Acceleration                  -0.474288   -0.468392
# SprintSpeed                   -0.526274   -0.518505
# Agility                       -0.473938   -0.473116
# Reactions                     -0.026467   -0.028999
# Balance                       -0.489752   -0.487717
# ShotPower                     -0.665950   -0.671035
# Jumping                       -0.109063   -0.117087
# Stamina                       -0.692279   -0.695565
# Strength                      -0.131612   -0.142008
# LongShots                     -0.632999   -0.633121
# Aggression                    -0.593370   -0.603008
# Interceptions                 -0.474944   -0.486682
# Positioning                   -0.686423   -0.689099
# Vision                        -0.334211   -0.337613
# Penalties                     -0.558359   -0.554646
# Composure                     -0.327524   -0.330095
# Marking                       -0.541607   -0.554152
# StandingTackle                -0.533361   -0.545950
# SlidingTackle                 -0.502082   -0.513983
# GKDiving                       0.979212    0.980687
# GKHandling                     0.973721    0.977989
# GKKicking                      0.973161    0.973406
# GKPositioning                  1.000000    0.977993
# GKReflexes                     0.977993    1.000000
#
# [39 rows x 39 columns]

# %%
#looking at the wages of the teams In EPL
wages=EPL["Wage"].str.replace('[€,M,K]',"")
new_wages=wages.astype("int")
EPL=EPL['Club']
plt.title("Distribution of the wages of the teams in EPL")
plt.bar(EPL,new_wages.sort_values(ascending=False))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # ANALYSIS OF LA LIGA TEAMS

# %%
#creating a list of laliga teams 
laliga=["FC Barcelona", "Real Madrid","CA Osasuna", "Villareal CF", "Real Sociedad", "Real Betis", "Deportivo Alavés",
        'Athletic Club de Bilbao',"Sevilla FC","RC Celta","Real Valladolid CF",'Valencia CF', 'RC Celta',
        "SD Huesca","SD Eibar", "Elche CF",
        "Granada CF", 'Getafe CF',"Levante UD",'RCD Espanyol','Cádiz CF','Atlético Madrd']
laliga=data[data["Club"].isin(laliga)]


laliga
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 0               0  158023       L. Messi   31
# 6               6  177003      L. Modrić   32
# 7               7  176580      L. Suárez   31
# 8               8  155862   Sergio Ramos   32
# 11             11  182521       T. Kroos   28
# ...           ...     ...            ...  ...
# 16756       16756  246593         Javito   17
# 16803       16803  222569        Pedrosa   21
# 17043       17043  220190  Cristian Arco   23
# 17116       17116  245597   Víctor Gómez   18
# 17299       17299  246035      F. Macias   19
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 6      https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7      https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8      https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 11     https://cdn.sofifa.org/players/4/19/182521.png     Germany
# ...                                               ...         ...
# 16756  https://cdn.sofifa.org/players/4/19/246593.png       Spain
# 16803  https://cdn.sofifa.org/players/4/19/222569.png       Spain
# 17043  https://cdn.sofifa.org/players/4/19/220190.png       Spain
# 17116  https://cdn.sofifa.org/players/4/19/245597.png       Spain
# 17299  https://cdn.sofifa.org/players/4/19/246035.png   Venezuela
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 6      https://cdn.sofifa.org/flags/10.png       91         91
# 7      https://cdn.sofifa.org/flags/60.png       91         91
# 8      https://cdn.sofifa.org/flags/45.png       91         91
# 11     https://cdn.sofifa.org/flags/21.png       90         90
# ...                                    ...      ...        ...
# 16756  https://cdn.sofifa.org/flags/45.png       56         72
# 16803  https://cdn.sofifa.org/flags/45.png       56         64
# 17043  https://cdn.sofifa.org/flags/45.png       55         61
# 17116  https://cdn.sofifa.org/flags/45.png       55         73
# 17299  https://cdn.sofifa.org/flags/61.png       54         69
#
#                      Club  ... Composure Marking StandingTackle  \
# 0            FC Barcelona  ...      96.0    33.0           28.0
# 6             Real Madrid  ...      84.0    60.0           76.0
# 7            FC Barcelona  ...      85.0    62.0           45.0
# 8             Real Madrid  ...      82.0    87.0           92.0
# 11            Real Madrid  ...      85.0    72.0           79.0
# ...                   ...  ...       ...     ...            ...
# 16756           SD Huesca  ...      50.0    60.0           51.0
# 16803  Real Valladolid CF  ...      48.0    28.0           16.0
# 17043            Cádiz CF  ...      24.0    12.0           19.0
# 17116        RCD Espanyol  ...      42.0    56.0           48.0
# 17299           SD Huesca  ...      51.0    22.0           15.0
#
#        SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning  \
# 0               26.0      6.0        11.0       15.0           14.0
# 6               73.0     13.0         9.0        7.0           14.0
# 7               38.0     27.0        25.0       31.0           33.0
# 8               91.0     11.0         8.0        9.0            7.0
# 11              69.0     10.0        11.0       13.0            7.0
# ...              ...      ...         ...        ...            ...
# 16756           51.0     12.0        14.0       11.0            7.0
# 16803           23.0     11.0        16.0        7.0           14.0
# 17043           17.0     56.0        53.0       55.0           53.0
# 17116           46.0     11.0         9.0       12.0           12.0
# 17299           15.0     15.0        15.0       14.0           15.0
#
#       GKReflexes Release Clause
# 0            8.0        €226.5M
# 6            9.0        €137.4M
# 7           37.0          €164M
# 8           11.0        €104.6M
# 11          10.0        €156.8M
# ...          ...            ...
# 16756        8.0          €452K
# 16803        9.0          €336K
# 17043       52.0          €162K
# 17116        6.0          €436K
# 17299        8.0          €424K
#
# [566 rows x 89 columns]

# %%
#teams with their number of players 
laliga.Club.value_counts()
# Out:
# Valencia CF                33
# Real Madrid                33
# FC Barcelona               33
# RC Celta                   33
# Levante UD                 32
# Athletic Club de Bilbao    31
# Real Sociedad              31
# Cádiz CF                   30
# Sevilla FC                 30
# SD Huesca                  30
# Real Valladolid CF         30
# RCD Espanyol               29
# SD Eibar                   29
# Granada CF                 29
# Getafe CF                  28
# Deportivo Alavés           27
# Real Betis                 27
# Elche CF                   26
# CA Osasuna                 25
# Name: Club, dtype: int64

# %%
#looking at the number of p[layers in each of the countries  whose players are in the LA Liga 
liga=laliga["Nationality"].value_counts()
liga
# Out:
# Spain                   385
# Argentina                20
# France                   19
# Brazil                   18
# Portugal                 14
# Colombia                  9
# Uruguay                   9
# Serbia                    8
# Ghana                     5
# Denmark                   5
# Turkey                    4
# Nigeria                   4
# Belgium                   4
# Venezuela                 4
# Senegal                   4
# Mexico                    3
# Paraguay                  3
# Chile                     3
# Germany                   3
# Italy                     3
# Croatia                   3
# Morocco                   3
# Cameroon                  2
# Netherlands               2
# Slovakia                  2
# Japan                     2
# Romania                   2
# Costa Rica                2
# Algeria                   2
# Montenegro                2
# Equatorial Guinea         2
# Guinea                    1
# Ukraine                   1
# Ivory Coast               1
# Korea Republic            1
# Russia                    1
# Bosnia Herzegovina        1
# Central African Rep.      1
# Wales                     1
# FYR Macedonia             1
# Dominican Republic        1
# Albania                   1
# Togo                      1
# Switzerland               1
# Sweden                    1
# Czech Republic            1
# Name: Nationality, dtype: int64

# %%
liga_intl=liga.count()
print("there are", liga_intl, "players who plays for their national teams in LA Liga ")
# Out:
# there are 46 players who plays for their national teams in LA Liga

# %%
#total and average number of players in LA liga
total_players=laliga["Name"].count()
teams=laliga["Club"].unique()
average_players_laliga=total_players/len(teams)
print("There are a total of",total_players, "players in laliga",".""on average, there are",average_players_laliga, "in each team in laliga")
# Out:
# There are a total of 566 players in laliga .on average, there are 29.789473684210527 in each team in laliga

# %%
#statistical representation of LA Liga 
laliga.describe()
# Out:
#          Unnamed: 0             ID         Age     Overall   Potential  \
# count    566.000000     566.000000  566.000000  566.000000  566.000000
# mean    5049.212014  213115.121908   24.856890   72.270318   77.427562
# std     4878.522513   27981.581541    4.426271    7.298399    5.779201
# min        0.000000   45186.000000   17.000000   54.000000   61.000000
# 25%      971.250000  198429.500000   21.000000   67.000000   73.000000
# 50%     2965.500000  219423.000000   24.000000   73.000000   77.000000
# 75%     8421.000000  235944.750000   28.000000   77.000000   81.000000
# max    17299.000000  246616.000000   39.000000   94.000000   94.000000
#
#            Special  International Reputation   Weak Foot  Skill Moves  \
# count   566.000000                566.000000  566.000000   566.000000
# mean   1712.911661                  1.302120    3.061837     2.577739
# std     289.626136                  0.680106    0.599167     0.876517
# min     895.000000                  1.000000    1.000000     1.000000
# 25%    1568.000000                  1.000000    3.000000     2.000000
# 50%    1757.000000                  1.000000    3.000000     3.000000
# 75%    1926.000000                  1.000000    3.000000     3.000000
# max    2346.000000                  5.000000    5.000000     5.000000
#
#        Jersey Number  ...   Penalties   Composure     Marking  StandingTackle  \
# count     566.000000  ...  566.000000  566.000000  566.000000      566.000000
# mean       17.162544  ...   51.708481   63.420495   51.636042       51.784452
# std        10.237623  ...   16.930409   11.703862   20.170118       24.272702
# min         1.000000  ...    9.000000   23.000000    8.000000       10.000000
# 25%         8.000000  ...   41.250000   56.000000   35.000000       28.000000
# 50%        17.000000  ...   52.000000   64.000000   56.000000       62.000000
# 75%        25.000000  ...   64.750000   71.000000   68.000000       73.750000
# max        41.000000  ...   90.000000   96.000000   91.000000       92.000000
#
#        SlidingTackle    GKDiving  GKHandling   GKKicking  GKPositioning  \
# count     566.000000  566.000000  566.000000  566.000000     566.000000
# mean       49.408127   17.461131   17.397527   16.807420      17.473498
# std        24.218136   19.712116   18.999281   18.376977      18.915420
# min        10.000000    4.000000    2.000000    4.000000       2.000000
# 25%        25.250000    9.000000    8.250000    8.000000       9.000000
# 50%        56.000000   11.000000   12.000000   11.000000      12.000000
# 75%        71.000000   14.000000   14.000000   14.000000      14.000000
# max        91.000000   90.000000   91.000000   88.000000      86.000000
#
#        GKReflexes
# count  566.000000
# mean    17.295053
# std     19.635787
# min      4.000000
# 25%      8.000000
# 50%     11.000000
# 75%     14.000000
# max     90.000000
#
# [8 rows x 44 columns]

# %%
#heatmap of LA Liga players
plt.figure(figsize=(10,8))
plt.title("Heatmap showing the relationship of the various features of players in LA liga")
sns.heatmap(laliga[['Age','Crossing', 'International Reputation',
       'Skill Moves', 'Work Rate', 'Body Type','Overall', 'Potential', 'Value', 'Wage',
       'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
       'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']].corr(), linewidth=.5)
plt.show()

# %%
plt.scatter(laliga["Acceleration"], laliga["LongPassing"])
plt.title("Distribution of the relationship between acceleration and long passing")
plt.xlabel("Acceleration")
plt.ylabel("LongPassing")
plt.show()
print("from the graph, it can be deduced that, acceleration and long passing are positively correlated. which means that a player "
       "who has a high acceleration is also good in giving long passes")
# Out:
# from the graph, it can be deduced that, acceleration and long passing are positively correlated. which means that a player who has a high acceleration is also good in giving long passes

# %%
#looking at the wages of the teams In laliga
wages=laliga["Wage"].str.replace('[€,M,K]',"")
new_wages=wages.astype("int")
laliga_teams=laliga['Club']
plt.title("Distribution of the wages of the teams in La Liga")
plt.bar(laliga_teams, new_wages)
plt.xticks(rotation=90)
plt.show()

# %%
#looking at the overall rating of the teams In laliga

laliga_teams=laliga['Club']
overall=laliga['Overall']
plt.title("Distribution of the wages of the teams in La Liga")
plt.bar(laliga_teams, overall)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # COMPARISON BETWEEN LALIGA AND EPL PLAYERS(age and rating)

# %%
#age distribution of players in LA liga
plt.title("age distribution of LA Liga players")
laliga_age=laliga["Age"]
plt.hist(laliga_age)
plt.xlabel("Age")
plt.ylabel("number of players")
plt.show()

# %%
#LaliGA overall rating
overall=laliga["Overall"]
plt.title("Distribution of overall ratings of LA Liga players")
plt.hist(overall)
plt.xlabel("overall rating")
plt.ylabel("Number of players")
plt.show()

# %%
laliga_shot=laliga["ShotPower"]
plt.title("Distribution of shot power in LA liga")
plt.hist(laliga_shot)
plt.show()

# %%
#statistical description of LA Liga players 
laliga.describe()

# %%
pen=laliga.loc[laliga["Penalties"].idxmax()]
pen["Name"]
pen["Club"]
pen["Nationality"]
print("The best penalty taker in laliga is", pen["Name"], "plays for",pen["Club"],"and from",pen["Nationality"])

# %%
#statistical description of EPL players
EPL.describe()
